# %%
# !pip install torch transformers bitsandbytes accelerate sqlparse
# Out:
# Requirement already satisfied: torch in /opt/conda/lib/python3.10/site-packages (2.1.2)
# Requirement already satisfied: transformers in /opt/conda/lib/python3.10/site-packages (4.38.2)
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.43.0-py3-none-manylinux_2_24_x86_64.whl.metadata (1.8 kB)
# Requirement already satisfied: accelerate in /opt/conda/lib/python3.10/site-packages (0.28.0)
# Requirement already satisfied: sqlparse in /opt/conda/lib/python3.10/site-packages (0.4.4)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch) (4.9.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch) (2024.3.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /opt/conda/lib/python3.10/site-packages (from transformers) (0.21.4)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from transformers) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from transformers) (2023.12.25)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /opt/conda/lib/python3.10/site-packages (from transformers) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/conda/lib/python3.10/site-packages (from transformers) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in /opt/conda/lib/python3.10/site-packages (from transformers) (4.66.1)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from accelerate) (5.9.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->transformers) (3.1.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch) (1.3.0)
# Downloading bitsandbytes-0.43.0-py3-none-manylinux_2_24_x86_64.whl (102.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.2/102.2 MB 15.2 MB/s eta 0:00:0000:0100:01
# Installing collected packages: bitsandbytes
# Successfully installed bitsandbytes-0.43.0

# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM

# %%
torch.cuda.is_available()
# Out:
# True

# %%
available_memory = torch.cuda.get_device_properties(0).total_memory

# %%
print(available_memory)
# Out:
# 17066885120

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %%
# Cloning the GitHub repository
# !git clone -q https://github.com/glee4810/ehrsql-2024.git
# %cd ehrsql-2024
# Out:
# /kaggle/working/ehrsql-2024

# %%
import os
import json
import pandas as pd

# Directory paths for database, results and scoring program
DB_ID = 'mimic_iv'
BASE_DATA_DIR = 'data/mimic_iv'
RESULT_DIR = 'sample_result_submission/'
SCORE_PROGRAM_DIR = 'scoring_program/'

# File paths for the dataset and labels
TABLES_PATH = os.path.join('data', DB_ID, 'tables.json')               # JSON containing database schema
TRAIN_DATA_PATH = os.path.join(BASE_DATA_DIR, 'train', 'data.json')    # JSON file with natural language questions for training data
TRAIN_LABEL_PATH = os.path.join(BASE_DATA_DIR, 'train', 'label.json')  # JSON file with corresponding SQL queries for training data
VALID_DATA_PATH = os.path.join(BASE_DATA_DIR, 'test', 'data.json')    # JSON file for validation data
DB_PATH = os.path.join('data', DB_ID, f'{DB_ID}.sqlite')               # Database path

# %%
# !wget https://physionet.org/static/published-projects/mimic-iv-demo/mimic-iv-clinical-database-demo-2.2.zip
# !unzip mimic-iv-clinical-database-demo-2.2
# !gunzip -r mimic-iv-clinical-database-demo-2.2
# Out:
# --2024-03-26 07:22:18--  https://physionet.org/static/published-projects/mimic-iv-demo/mimic-iv-clinical-database-demo-2.2.zip
# Resolving physionet.org (physionet.org)... 18.18.42.54
# Connecting to physionet.org (physionet.org)|18.18.42.54|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 16189661 (15M) [application/zip]
# Saving to: 'mimic-iv-clinical-database-demo-2.2.zip'
#
# mimic-iv-clinical-d 100%[===================>]  15.44M   154KB/s    in 80s
#
# 2024-03-26 07:23:39 (198 KB/s) - 'mimic-iv-clinical-database-demo-2.2.zip' saved [16189661/16189661]
#
# Archive:  mimic-iv-clinical-database-demo-2.2.zip
#   inflating: mimic-iv-clinical-database-demo-2.2/LICENSE.txt
#   inflating: mimic-iv-clinical-database-demo-2.2/README.txt
#   inflating: mimic-iv-clinical-database-demo-2.2/SHA256SUMS.txt
#   inflating: mimic-iv-clinical-database-demo-2.2/demo_subject_id.csv
#  extracting: mimic-iv-clinical-database-demo-2.2/hosp/admissions.csv.gz
#   inflating: mimic-iv-clinical-database-demo-2.2/hosp/d_hcpcs.csv.gz
#   inflating: mimic-iv-clinical-database-demo-2.2/hosp/d_icd_diagnoses.csv.gz
#   inflating: mimic-iv-clinical-database-demo-2.2/hosp/d_icd_procedures.csv.gz
#  extracting: mimic-iv-clinical-database-demo-2.2/hosp/d_labitems.csv.gz
#  extracting: mimic-iv-clinical-database-demo-2.2/hosp/diagnoses_icd.csv.gz
#  extracting: mimic-iv-clinical-database-demo-2.2/hosp/drgcodes.csv.gz
#   inflating: mimic-iv-clinical-database-demo-2.2/hosp/emar.csv.gz
#   inflating: mimic-iv-clinical-database-demo-2.2/hosp/emar_detail.csv.gz
#  extracting: mimic-iv-clinical-database-demo-2.2/hosp/hcpcsevents.csv.gz
#   inflating: mimic-iv-clinical-database-demo-2.2/hosp/labevents.csv.gz
#   inflating: mimic-iv-clinical-database-demo-2.2/hosp/microbiologyevents.csv.gz
#  extracting: mimic-iv-clinical-database-demo-2.2/hosp/omr.csv.gz
#  extracting: mimic-iv-clinical-database-demo-2.2/hosp/patients.csv.gz
#   inflating: mimic-iv-clinical-database-demo-2.2/hosp/pharmacy.csv.gz
#   inflating: mimic-iv-clinical-database-demo-2.2/hosp/poe.csv.gz
#   inflating: mimic-iv-clinical-database-demo-2.2/hosp/poe_detail.csv.gz
#   inflating: mimic-iv-clinical-database-demo-2.2/hosp/prescriptions.csv.gz
#  extracting: mimic-iv-clinical-database-demo-2.2/hosp/procedures_icd.csv.gz
#   inflating: mimic-iv-clinical-database-demo-2.2/hosp/provider.csv.gz
#  extracting: mimic-iv-clinical-database-demo-2.2/hosp/services.csv.gz
#  extracting: mimic-iv-clinical-database-demo-2.2/hosp/transfers.csv.gz
#   inflating: mimic-iv-clinical-database-demo-2.2/icu/caregiver.csv.gz
#   inflating: mimic-iv-clinical-database-demo-2.2/icu/chartevents.csv.gz
#   inflating: mimic-iv-clinical-database-demo-2.2/icu/d_items.csv.gz
#   inflating: mimic-iv-clinical-database-demo-2.2/icu/datetimeevents.csv.gz
#  extracting: mimic-iv-clinical-database-demo-2.2/icu/icustays.csv.gz
#   inflating: mimic-iv-clinical-database-demo-2.2/icu/ingredientevents.csv.gz
#   inflating: mimic-iv-clinical-database-demo-2.2/icu/inputevents.csv.gz
#   inflating: mimic-iv-clinical-database-demo-2.2/icu/outputevents.csv.gz
#   inflating: mimic-iv-clinical-database-demo-2.2/icu/procedureevents.csv.gz

# %%
# %cd preprocess
# !bash preprocess.sh
# %cd ..
# Out:
# /kaggle/working/ehrsql-2024/preprocess
# timeshift is True
# start_year: 2100
# time_span: 0
# current_time: 2100-12-31 23:59:00
# Processing patients, admissions, icustays, transfers
# Cannot take a larger sample than population when 'replace=False
# Use all available patients instead.
# num_cur_patient: 4
# num_non_cur_patient: 90
# num_patient: 94
# patients, admissions, icustays, transfers processed (took 0.2297 secs)
# Processing dictionary tables (d_icd_diagnoses, d_icd_procedures, d_labitems, d_items)
# d_icd_diagnoses, d_icd_procedures, d_labitems, d_items processed (took 2.5758 secs)
# Processing diagnoses_icd table
# diagnoses_icd processed (took 0.1616 secs)
# Processing procedures_icd table
# procedures_icd processed (took 0.0604 secs)
# Processing labevents table
# labevents processed (took 2.7756 secs)
# Processing prescriptions table
# prescriptions processed (took 0.8669 secs)
# Processing COST table
# cost processed (took 0.6457 secs)
# Processing chartevents table
# chartevents processed (took 4.2733 secs)
# Processing inputevents table
# inputevents processed (took 0.6459 secs)
# Processing outputevents table
# outputevents processed (took 0.4442 secs)
# Processing microbiologyevents table
# microbiologyevents processed (took 0.1113 secs)
# 0               patients
# 1             admissions
# 2        d_icd_diagnoses
# 3       d_icd_procedures
# 4             d_labitems
# 5                d_items
# 6          diagnoses_icd
# 7         procedures_icd
# 8              labevents
# 9          prescriptions
# 10                  cost
# 11           chartevents
# 12           inputevents
# 13          outputevents
# 14    microbiologyevents
# 15              icustays
# 16             transfers
# Name: name, dtype: object
# Done!
#
# /kaggle/working/ehrsql-2024

# %%
from utils.data_io import read_json as read_data

train_data = read_data(TRAIN_DATA_PATH)
train_label = read_data(TRAIN_LABEL_PATH)

valid_data = read_data(VALID_DATA_PATH)

# %%
print("Train data:", (len(train_data['data']), len(train_label)))
print("Valid data:", len(valid_data['data']))
# Out:
# Train data: (5124, 5124)
# Valid data: 1167

# %%
# Explore keys and data structure
print(train_data.keys())
print(train_data['version'])
print(train_data['data'][0]['id'])
print(train_data['data'][0]['question'])

# Explore the label structure
# print(train_label.keys())
# print(train_label[list(train_label.keys())[0]])
# Out:
# dict_keys(['version', 'data'])
# mimic_iv_demo_1.0_train
# 3b9849548e56c59f768d5447
# Tell me the minimum respiratory rate in patient 10021118 in the first ICU visit.

# %% [markdown]
# Model Building Starts

# %%
# !pip install accelerate
# Out:
# Requirement already satisfied: accelerate in /opt/conda/lib/python3.10/site-packages (0.28.0)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from accelerate) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from accelerate) (21.3)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from accelerate) (5.9.3)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from accelerate) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /opt/conda/lib/python3.10/site-packages (from accelerate) (2.1.2)
# Requirement already satisfied: huggingface-hub in /opt/conda/lib/python3.10/site-packages (from accelerate) (0.21.4)
# Requirement already satisfied: safetensors>=0.3.1 in /opt/conda/lib/python3.10/site-packages (from accelerate) (0.4.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->accelerate) (3.1.1)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (3.13.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (4.9.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (2024.3.0)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from huggingface-hub->accelerate) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub->accelerate) (4.66.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub->accelerate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub->accelerate) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub->accelerate) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub->accelerate) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)

# %%
model_name = "defog/sqlcoder-7b-2"
tokenizer = AutoTokenizer.from_pretrained(model_name)
# if available_memory > 17e9:
#     # if you have atleast 16GB of GPU memory, run load the model in float16
#     model = AutoModelForCausalLM.from_pretrained(
#         model_name,
#         trust_remote_code=True,
#         torch_dtype=torch.float16,
#         device_map="auto",
#         use_cache=True,
#     )
# else:
    # else, load in 8 bits – this is a bit slower
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    trust_remote_code=True,
    # torch_dtype=torch.float16,
    load_in_4bit=True,
    device_map="auto",
    use_cache=True,
)
# Out:
# tokenizer_config.json:   0%|          | 0.00/1.84k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/515 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/691 [00:00<?, ?B/s]
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.
# model.safetensors.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/3 [00:00<?, ?it/s]
# model-00001-of-00003.safetensors:   0%|          | 0.00/4.94G [00:00<?, ?B/s]
# model-00002-of-00003.safetensors:   0%|          | 0.00/4.95G [00:00<?, ?B/s]
# model-00003-of-00003.safetensors:   0%|          | 0.00/3.59G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/111 [00:00<?, ?B/s]

# %%
prompt = """### Task
Generate a SQL query to answer [QUESTION]{question}[/QUESTION]

### Instructions
- If you cannot answer the question with the available database schema, return 'Humne kiya'
- Remember that revenue is price multiplied by quantity
- Remember that cost is supply_price multiplied by quantity

### Database Schema
This query will run on a database whose schema is represented in this string:

DROP TABLE IF EXISTS patients;
CREATE TABLE patients 
(
    row_id INT NOT NULL PRIMARY KEY,
    subject_id INT NOT NULL UNIQUE,
    gender VARCHAR(5) NOT NULL,
    dob TIMESTAMP(0) NOT NULL,
    dod TIMESTAMP(0)
);

DROP TABLE IF EXISTS admissions;
CREATE TABLE admissions
(
    row_id INT NOT NULL PRIMARY KEY,
    subject_id INT NOT NULL,
    hadm_id INT NOT NULL UNIQUE,
    admittime TIMESTAMP(0) NOT NULL,
    dischtime TIMESTAMP(0),
    admission_type VARCHAR(50) NOT NULL,
    admission_location VARCHAR(50) NOT NULL,
    discharge_location VARCHAR(50),
    insurance VARCHAR(255) NOT NULL,
    language VARCHAR(10),
    marital_status VARCHAR(50),
    age INT NOT NULL,
    FOREIGN KEY(subject_id) REFERENCES patients(subject_id)
);

DROP TABLE IF EXISTS d_icd_diagnoses;
CREATE TABLE d_icd_diagnoses
(
    row_id INT NOT NULL PRIMARY KEY,
    icd_code VARCHAR(10) NOT NULL UNIQUE,
    long_title VARCHAR(255) NOT NULL
);

DROP TABLE IF EXISTS d_icd_procedures;
CREATE TABLE d_icd_procedures 
(
    row_id INT NOT NULL PRIMARY KEY,
    icd_code VARCHAR(10) NOT NULL UNIQUE,
    long_title VARCHAR(255) NOT NULL
);

DROP TABLE IF EXISTS d_labitems;
CREATE TABLE d_labitems 
(
    row_id INT NOT NULL PRIMARY KEY,
    itemid INT NOT NULL UNIQUE,
    label VARCHAR(200)
);

DROP TABLE IF EXISTS d_items;
CREATE TABLE d_items 
(
    row_id INT NOT NULL PRIMARY KEY,
    itemid INT NOT NULL UNIQUE,
    label VARCHAR(200) NOT NULL,
    abbreviation VARCHAR(200) NOT NULL,
    linksto VARCHAR(50) NOT NULL
);

DROP TABLE IF EXISTS diagnoses_icd;
CREATE TABLE diagnoses_icd
(
    row_id INT NOT NULL PRIMARY KEY,
    subject_id INT NOT NULL,
    hadm_id INT NOT NULL,
    icd_code VARCHAR(10) NOT NULL,
    charttime TIMESTAMP(0) NOT NULL,
    FOREIGN KEY(hadm_id) REFERENCES admissions(hadm_id),
    FOREIGN KEY(icd_code) REFERENCES d_icd_diagnoses(icd_code)
);

DROP TABLE IF EXISTS procedures_icd;
CREATE TABLE procedures_icd
(
    row_id INT NOT NULL PRIMARY KEY,
    subject_id INT NOT NULL,
    hadm_id INT NOT NULL,
    icd_code VARCHAR(10) NOT NULL,
    charttime TIMESTAMP(0) NOT NULL,
    FOREIGN KEY(hadm_id) REFERENCES admissions(hadm_id),
    FOREIGN KEY(icd_code) REFERENCES d_icd_procedures(icd_code)
);

DROP TABLE IF EXISTS labevents;
CREATE TABLE labevents
(
    row_id INT NOT NULL PRIMARY KEY,
    subject_id INT NOT NULL,
    hadm_id INT NOT NULL,
    itemid INT NOT NULL,
    charttime TIMESTAMP(0),
    valuenum DOUBLE PRECISION,
    valueuom VARCHAR(20),
    FOREIGN KEY(hadm_id) REFERENCES admissions(hadm_id),
    FOREIGN KEY(itemid) REFERENCES d_labitems(itemid)
);

DROP TABLE IF EXISTS prescriptions;
CREATE TABLE prescriptions
(
    row_id INT NOT NULL PRIMARY KEY,
    subject_id INT NOT NULL,
    hadm_id INT NOT NULL,
    starttime TIMESTAMP(0) NOT NULL,
    stoptime TIMESTAMP(0),
    drug VARCHAR(255) NOT NULL,
    dose_val_rx VARCHAR(100) NOT NULL,
    dose_unit_rx VARCHAR(50) NOT NULL,
    route VARCHAR(50) NOT NULL,
    FOREIGN KEY(hadm_id) REFERENCES admissions(hadm_id)
);

DROP TABLE IF EXISTS cost;
CREATE TABLE cost
(
    row_id INT NOT NULL PRIMARY KEY,
    subject_id INT NOT NULL,
    hadm_id INT NOT NULL,
    event_type VARCHAR(20) NOT NULL,
    event_id INT NOT NULL,
    chargetime TIMESTAMP(0) NOT NULL,
    cost DOUBLE PRECISION NOT NULL,
    FOREIGN KEY(hadm_id) REFERENCES admissions(hadm_id),
    FOREIGN KEY(event_id) REFERENCES diagnoses_icd(row_id),
    FOREIGN KEY(event_id) REFERENCES procedures_icd(row_id),
    FOREIGN KEY(event_id) REFERENCES labevents(row_id),
    FOREIGN KEY(event_id) REFERENCES prescriptions(row_id)  
);

DROP TABLE IF EXISTS chartevents;
CREATE TABLE chartevents
(
    row_id INT NOT NULL PRIMARY KEY,
    subject_id INT NOT NULL,
    hadm_id INT NOT NULL,
    stay_id INT NOT NULL,
    itemid INT NOT NULL,
    charttime TIMESTAMP(0) NOT NULL,
    valuenum DOUBLE PRECISION,
    valueuom VARCHAR(50),
    FOREIGN KEY(hadm_id) REFERENCES admissions(hadm_id),
    FOREIGN KEY(stay_id) REFERENCES icustays(stay_id),
    FOREIGN KEY(itemid) REFERENCES d_items(itemid)
);

DROP TABLE IF EXISTS inputevents;
CREATE TABLE inputevents
(
    row_id INT NOT NULL PRIMARY KEY,
    subject_id INT NOT NULL,
    hadm_id INT NOT NULL,
    stay_id INT NOT NULL,
    starttime TIMESTAMP(0) NOT NULL,
    itemid INT NOT NULL,
    amount DOUBLE PRECISION,
    FOREIGN KEY(hadm_id) REFERENCES admissions(hadm_id),
    FOREIGN KEY(stay_id) REFERENCES icustays(stay_id),
    FOREIGN KEY(itemid) REFERENCES d_items(itemid)
);

DROP TABLE IF EXISTS outputevents;
CREATE TABLE outputevents
(
    row_id INT NOT NULL PRIMARY KEY,
    subject_id INT NOT NULL,
    hadm_id INT NOT NULL,
    stay_id INT NOT NULL,
    charttime TIMESTAMP(0) NOT NULL,
    itemid INT NOT NULL,
    value DOUBLE PRECISION,
    FOREIGN KEY(hadm_id) REFERENCES admissions(hadm_id),
    FOREIGN KEY(stay_id) REFERENCES icustays(stay_id),
    FOREIGN KEY(itemid) REFERENCES d_items(itemid)
);

DROP TABLE IF EXISTS microbiologyevents;
CREATE TABLE microbiologyevents
(
    row_id INT NOT NULL PRIMARY KEY,
    subject_id INT NOT NULL,
    hadm_id INT NOT NULL,
    charttime TIMESTAMP(0) NOT NULL,
    spec_type_desc VARCHAR(100),
    test_name VARCHAR(100),
    org_name VARCHAR(100),
    FOREIGN KEY(hadm_id) REFERENCES admissions(hadm_id)
);

DROP TABLE IF EXISTS icustays;
CREATE TABLE icustays
(
    row_id INT NOT NULL PRIMARY KEY,
    subject_id INT NOT NULL,
    hadm_id INT NOT NULL,
    stay_id INT NOT NULL UNIQUE,
    first_careunit VARCHAR(20) NOT NULL,
    last_careunit VARCHAR(20) NOT NULL,
    intime TIMESTAMP(0) NOT NULL,
    outtime TIMESTAMP(0),
    FOREIGN KEY(hadm_id) REFERENCES admissions(hadm_id)
);

DROP TABLE IF EXISTS transfers;
CREATE TABLE transfers
(
    row_id INT NOT NULL PRIMARY KEY,
    subject_id INT NOT NULL,
    hadm_id INT NOT NULL,
    transfer_id INT NOT NULL,
    eventtype VARCHAR(20) NOT NULL,
    careunit VARCHAR(20),
    intime TIMESTAMP(0) NOT NULL,
    outtime TIMESTAMP(0),
    FOREIGN KEY(hadm_id) REFERENCES admissions(hadm_id)
);


### Answer
Given the database schema, here is the SQL query that answers [QUESTION]{question}[/QUESTION]
[SQL]
"""

# %%
import sqlparse

def generate_query(question):
    updated_prompt = prompt.format(question=question)
    inputs = tokenizer(updated_prompt, return_tensors="pt").to("cuda")
    generated_ids = model.generate(
        **inputs,
        num_return_sequences=1,
        eos_token_id=tokenizer.eos_token_id,
        pad_token_id=tokenizer.eos_token_id,
        max_new_tokens=400,
        do_sample=False,
        num_beams=1,
    )

    outputs = tokenizer.batch_decode(generated_ids, skip_special_tokens=True)

    torch.cuda.empty_cache()
    torch.cuda.synchronize()
    # empty cache so that you do generate more results w/o memory crashing
    # particularly important on Colab – memory management is much more straightforward
    # when running on an inference service
    return sqlparse.format(outputs[0].split("[SQL]")[-1], reindent=True)

# %%
questions=[]
ids = []
length = len(valid_data['data'])
print(length)
for i in range (length):
    questions.append(valid_data['data'][i]['question'])
    ids.append(valid_data['data'][i]['id'])
#questions
# Out:
# 1167

# %%
sqls = []
i = 0

# Open a text file in write mode
with open("queries.txt", "w") as file:
    file.write('{')
    for question in questions:
        sql = generate_query(question)
        if 'Humne kiya' in sql:
            sql = 'null'
        sql = sql.replace('\n', '')
        sql = sql.replace(';','')
        sqls.append(sql)
        id=ids[i]
        print(id+":",end="")
        # Write the id and SQL query to the file within double quotes
        file.write(f'"{id}":"{sql}",\n')
        
        print(sql)
        i += 1
        print("Count is ", i)
    file.write('}')
    file.close()
# Out:
# /opt/conda/lib/python3.10/site-packages/bitsandbytes/nn/modules.py:391: UserWarning: Input type into Linear4bit is torch.float16, but bnb_4bit_compute_dtype=torch.float32 (default). This will lead to slow inference or training speed.
#   warnings.warn('Input type into Linear4bit is torch.float16, but bnb_4bit_compute_dtype=torch.float32 (default). This will lead to slow inference or training speed.')
# 2024-03-26 07:25:56.953115: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-26 07:25:56.953224: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-26 07:25:57.085603: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 282f008dd8dfb8f4a1dd6999:SELECT m.org_nameFROM microbiologyevents mJOIN  (SELECT s.subject_id,          MIN(m.charttime) AS min_charttime   FROM microbiologyevents m   JOIN admissions s ON m.hadm_id = s.hadm_id   WHERE s.subject_id = 10027602   GROUP BY s.subject_id) AS min_chart ON m.hadm_id = min_chart.subject_idWHERE m.test_name = 'Urine test'  AND m.spec_type_desc = 'Microorganism'
# Count is  1
# 47fd000ef0b1033a8aabfac8:SELECT p.drug,       COUNT(*) AS frequencyFROM prescriptions pWHERE EXTRACT(YEAR              FROM p.starttime) >= 2010GROUP BY p.drugORDER BY frequency DESCLIMIT 5
# Count is  2
# 7f07c59357750ac2b84e5221:SELECT m.spec_type_desc,       COUNT(*) AS frequencyFROM microbiologyevents mJOIN  (SELECT subject_id   FROM admissions   WHERE charttime >= (CURRENT_DATE - interval '2 months')     AND (icd_code = '757072'          OR icd_code = '757073')   GROUP BY subject_id) AS p ON m.subject_id = p.subject_idGROUP BY m.spec_type_descORDER BY frequency DESCLIMIT 5
# Count is  3
# c83990de3e5d2d218c83528a:null
# Count is  4
# f430a02bd152c617a86cd2c3:null
# Count is  5
# 34e18d3b9b2f055f37a2d04d:null
# Count is  6
# dfc058cc8e8d30a29c0177b9:SELECT COUNT(DISTINCT(p.subject_id)) AS patient_countFROM patients pJOIN diagnoses_icd d ON p.subject_id = d.subject_idJOIN admissions a ON p.subject_id = a.subject_idWHERE d.icd_code = 'thrombocytopenia, unspecified'  AND a.hadm_id IN    (SELECT hadm_id     FROM diagnoses_icd     WHERE icd_code = 'chronic airway obstruction, not elsewhere classified')
# Count is  7
# 4b10d0fec2f23acab915e3f3:SELECT COUNT(*)FROM  (SELECT DISTINCT(p.subject_id) AS patient_id   FROM patients p   JOIN admissions a ON p.subject_id = a.subject_id   JOIN procedures_icd pi ON a.hadm_id = pi.hadm_id   WHERE p.subject_id = 10004457     AND pi.icd_code = '423235'   LIMIT 2) AS subquery
# Count is  8
# 647bc08d18cac6dbda791c42:SELECT MAX(p.starttime) AS last_prescription_timeFROM prescriptions pWHERE p.subject_id = 10018845  AND p.route = 'sc'  AND EXTRACT(YEAR              FROM p.starttime) = 2010
# Count is  9
# 20c3ddd36c65c44890c3f3e5:SELECT m.test_nameFROM microbiologyevents mWHERE m.subject_id = 10021666  AND m.charttime > '2021-03-01'ORDER BY m.charttime ASCLIMIT 1
# Count is  10
# 5436413908d5e902536630e8:SELECT m.test_nameFROM microbiologyevents mJOIN  (SELECT s.subject_id,          MAX(m.charttime) AS max_charttime   FROM microbiologyevents m   JOIN patients s ON m.subject_id = s.subject_id   WHERE s.subject_id = 10018845     AND EXTRACT(YEAR                 FROM m.charttime) = 2021   GROUP BY s.subject_id) AS p ON m.subject_id = p.subject_idWHERE m.charttime = p.max_charttime
# Count is  11
# 4ea7d91dc5b0b0f4da0cb1c6:SELECT p.drug,       COUNT(*) AS COUNTFROM patients pJOIN prescriptions pr ON p.subject_id = pr.subject_idJOIN admissions a ON p.subject_id = a.subject_idWHERE p.drug ilike '%anemia%'  AND p.age >= 60  AND EXTRACT(YEAR              FROM a.admittime) = 2021GROUP BY p.drugORDER BY COUNT DESCLIMIT 3
# Count is  12
# 4f489c24ce6a5dfb8485d4f0:SELECT h.name AS hospital_name,       h.location AS hospital_locationFROM hospitals h
# Count is  13
# 2675abf72b38410bb4eda4ad:SELECT CAST(COUNT(DISTINCT CASE                               WHEN p.dod IS NOT NULL THEN p.subject_id                           END) AS FLOAT) / NULLIF(COUNT(DISTINCT p.subject_id), 0) AS proportionFROM patients pJOIN diagnoses_icd d ON p.subject_id = d.subject_idWHERE d.icd_code = 'A05.0'
# Count is  14
# 3fc7c5e0ee947f0f155f81ae:SELECT MIN(a.dischtime) AS earliest_dischargeFROM admissions aWHERE a.subject_id = 10004422  AND a.dischtime > '2021-01-01'
# Count is  15
# 647fbc4c18dc9b7300f25187:SELECT  (SELECT MIN(d.charttime)   FROM diagnoses_icd d   WHERE d.subject_id = 10021487     AND d.icd_code LIKE '%%other chronic nonalcoholic liver disease%%') -  (SELECT MIN(a.admittime)   FROM admissions a   WHERE a.subject_id = 10021487     AND a.hadm_id = 757071) AS days_since_first_diagnosis
# Count is  16
# 289be48fc696c588e5a69f9c:SELECT p.row_idFROM patients pJOIN diagnoses_icd d ON p.subject_id = d.subject_idWHERE d.icd_code = 'cataract extraction'
# Count is  17
# 3aa4a932c5d33d1b18e92ccc:null
# Count is  18
# 9e26fb10ef1cbf36ec4e516b:null
# Count is  19
# eeca589fced0d6ee197e6a2b:SELECT a.languageFROM admissions aWHERE a.marital_status = 'married'  AND a.age < 30
# Count is  20
# c59a0d9f2769a6133e2d4d28:null
# Count is  21
# 9dae764fbde5e025b480528a:SELECT p.row_id,       p.subject_id,       p.gender,       p.dob,       p.dod,       a.hadm_id,       a.admittime,       a.dischtime,       a.admission_type,       a.admission_location,       a.discharge_location,       a.insurance,       a.language,       a.marital_status,       a.age,       i.first_careunit,       i.last_careunit,       c.cost,       s.supply_price,       s.quantity,       s.revenue,       s.cost_per_unit,       s.procedure_code,       s.drug_code,       s.itemid,       s.label,       s.abbreviation,       s.linkstoFROM patients pJOIN admissions a ON p.subject_id = a.subject_idJOIN icustays i ON a.stay_id = i.stay_idJOIN suppliers s ON s.supplier_id = i.first_careunit
# Count is  22
# fa7797af0bc8368e7b76a129:SELECT  (SELECT labevents.valuenum   FROM labevents   JOIN admissions ON labevents.hadm_id = admissions.hadm_id   WHERE admissions.subject_id = 10004733     AND EXTRACT(HOUR                 FROM labevents.charttime) = 17     AND EXTRACT(MINUTE                 FROM labevents.charttime) = 0     AND EXTRACT(SECOND                 FROM labevents.charttime) = 0) -  (SELECT labevents.valuenum   FROM labevents   JOIN admissions ON labevents.hadm_id = admissions.hadm_id   WHERE admissions.subject_id = 10004733     AND EXTRACT(HOUR                 FROM labevents.charttime) = 16     AND EXTRACT(MINUTE                 FROM labevents.charttime) = 0     AND EXTRACT(SECOND                 FROM labevents.charttime) = 0) AS respiratory_rate_change
# Count is  23
# c1ba984738060f77fc1c4445:SELECT COUNT(DISTINCT a.subject_id) AS patient_countFROM admissions aWHERE a.dischtime BETWEEN (CURRENT_DATE - INTERVAL '1 year') AND CURRENT_DATE
# Count is  24
# 82af78058d47f0bdbcc12766:null
# Count is  25
# 14867be12327cc1d5dd7348f:null
# Count is  26
# d3f0d98539d2e9134a435816:SELECT EXTRACT(epoch               FROM (now() -                       (SELECT MIN(p.starttime)                        FROM prescriptions p                        WHERE p.subject_id = 10021487)))/3600 AS hours_passedFROM prescriptions
# Count is  27
# 61a3d12ba8e762f3b53709cd:SELECT m.test_name,       COUNT(*) AS frequencyFROM microbiologyevents mWHERE EXTRACT(YEAR              FROM m.charttime) >= 2010GROUP BY m.test_nameORDER BY frequency DESCLIMIT 5
# Count is  28
# 7e1f1fb83d613020a144d84d:null
# Count is  29
# e62aab7f7132343b9c06fb6a:null
# Count is  30
# 21d5909e4b60ccf617b739c8:SELECT d_icd_procedures.long_title,       COUNT(*) AS procedure_countFROM d_icd_proceduresJOIN procedures_icd ON d_icd_procedures.icd_code = procedures_icd.icd_codeJOIN admissions ON procedures_icd.hadm_id = admissions.hadm_idJOIN patients ON admissions.subject_id = patients.subject_idWHERE EXTRACT(YEAR              FROM admissions.admittime) = 2010  AND EXTRACT(MONTH              FROM admissions.admittime) = 1  AND patients.gender = 'M'  AND d_icd_procedures.long_title ILIKE '%right%heart%'GROUP BY d_icd_procedures.long_titleORDER BY procedure_count DESC NULLS LASTLIMIT 4
# Count is  31
# 67269f11d04e63d8d4a6aaf1:SELECT d_icd_procedures.long_title,       COUNT(*) AS procedure_countFROM patientsJOIN admissions ON patients.subject_id = admissions.subject_idJOIN diagnoses_icd ON admissions.hadm_id = diagnoses_icd.hadm_idJOIN procedures_icd ON admissions.hadm_id = procedures_icd.hadm_idJOIN d_icd_procedures ON procedures_icd.icd_code = d_icd_procedures.icd_codeWHERE patients.dod IS NULL  AND EXTRACT(YEAR              FROM admissions.dischtime) != 2021  AND EXTRACT(MONTH              FROM admissions.dischtime) = EXTRACT(MONTH                                                   FROM patients.dod)  AND d_icd_procedures.long_title not ilike '%complication%'  AND d_icd_procedures.long_title not ilike '%type%ii%'  AND d_icd_procedures.long_title not ilike '%unspecified%type%'GROUP BY d_icd_procedures.long_titleORDER BY procedure_count DESCLIMIT 5
# Count is  32
# 0c5a19d98fb21ee7f7415577:SELECT p.drugFROM prescriptions pJOIN admissions a ON p.hadm_id = a.hadm_idWHERE p.subject_id = 10021118  AND a.admittime >= date_trunc('month', CURRENT_DATE)  AND a.surgeon_name ILIKE '%left%internal%mammary%'  AND a.procedure_name ILIKE '%bypass%coronary%artery%'  AND a.procedure_name ILIKE '%open%approach%'ORDER BY p.starttime NULLS LAST
# Count is  33
# 2e40656c79819632933f3d54:SELECT COUNT(DISTINCT p.subject_id)FROM patients pJOIN procedures_icd pi ON p.subject_id = pi.subject_idJOIN d_icd_procedures d ON pi.icd_code = d.icd_codeWHERE d.long_title ilike '%right pleural cavity%drainage%device%percutaneous%approach%'
# Count is  34
# 5459fc4c053a74300114b32b:SELECT p.drug,       COUNT(*) AS COUNTFROM prescriptions pWHERE EXTRACT(YEAR              FROM p.starttime) >= 2010GROUP BY p.drugORDER BY COUNT DESCLIMIT 4
# Count is  35
# f7f4b0b9f1896ea6f3965250:SELECT COUNT(DISTINCT p.subject_id) AS number_of_patientsFROM patients pJOIN icustays i ON p.subject_id = i.subject_idWHERE i.first_careunit = 'Psychiatry'  AND EXTRACT(YEAR              FROM i.intime) >= 2021
# Count is  36
# 915a29cc5d0d25f775a9230e:SELECT COUNT(DISTINCT p.subject_id) AS num_patientsFROM prescriptions pWHERE p.drug ILIKE '%duloxetine%'  AND p.starttime >= (CURRENT_DATE - INTERVAL '1 year')
# Count is  37
# f9a4d8f655bc4658ff929dab:SELECT d_icd_procedures.long_title,       COUNT(*) AS procedure_countFROM patientsJOIN admissions ON patients.subject_id = admissions.subject_idJOIN procedures_icd ON admissions.hadm_id = procedures_icd.subject_idJOIN d_icd_procedures ON procedures_icd.icd_code = d_icd_procedures.icd_codeWHERE patients.subject_id IN    (SELECT patients.subject_id     FROM patients     JOIN admissions ON patients.subject_id = admissions.subject_id     JOIN procedures_icd ON admissions.hadm_id = procedures_icd.subject_id     JOIN d_icd_procedures ON procedures_icd.icd_code = d_icd_procedures.icd_code     WHERE d_icd_procedures.long_title ilike '%reposition%left%maxilla%with%external%fixation%device%percutaneous%approach%')GROUP BY d_icd_procedures.long_titleORDER BY procedure_count DESCLIMIT 3
# Count is  38
# 3daae260dfa809a3ad93e5bd:null
# Count is  39
# a7e5f65ddd31811247f49f56:null
# Count is  40
# 95259eb7cea07ea7f2a5cf48:null
# Count is  41
# a17ee07e69ba77566438512c:SELECT date_trunc('month', c.charttime) AS MONTH,       COUNT(*) AS total_tests,       COUNT(DISTINCT m.itemid) AS distinct_tests,       SUM(c.cost) AS total_cost,       SUM(c.cost * c.valuenum) AS total_cost_with_quantityFROM cost cJOIN labevents l ON c.event_id = l.row_idJOIN microbiologyevents m ON l.row_id = m.row_idWHERE date_part('year', c.charttime) = date_part('year', CURRENT_DATE)  AND m.spec_type_desc ILIKE '%tremor%'GROUP BY MONTHORDER BY total_tests DESC,         distinct_tests DESC,         total_cost DESC,         total_cost_with_quantity DESCLIMIT 4
# Count is  42
# 104c93f89e19274578bafb8d:SELECT MIN(a.admittime) AS first_admissionFROM patients pJOIN admissions a ON p.subject_id = a.subject_idJOIN procedures_icd pi ON a.hadm_id = pi.subject_idWHERE p.subject_id = 10038999  AND pi.icd_code = '12345'
# Count is  43
# d9b652601ec09231f9991b24:null
# Count is  44
# e0e182b93545a2f808a87836:null
# Count is  45
# 69c8cd3610b365b38e9dc8fb:null
# Count is  46
# 271fe9a047e24d8cef13cf91:null
# Count is  47
# 62967c2f2d2b967d2139be99:null
# Count is  48
# 297a1435453b2870054eb81d:null
# Count is  49
# 4a82faf774a9f3614964283f:SELECT o.nameFROM outputevents oJOIN patients p ON o.subject_id = p.subject_idWHERE p.subject_id = 10004720  AND o.charttime >= '2021-12-05'ORDER BY o.charttime DESCLIMIT 1
# Count is  50
# e4373b254aad4b11af3fda65:null
# Count is  51
# 729c62dcfd9ac11a32a56161:SELECT COUNT(p.drug) > 0 AS has_been_prescribedFROM prescriptions pWHERE p.subject_id = 10015860  AND p.starttime >= (CURRENT_DATE - INTERVAL '1 year')
# Count is  52
# 53eee4b8cfb226d8418ce3fa:SELECT d_icd_procedures.long_titleFROM patientsJOIN admissions ON patients.subject_id = admissions.subject_idJOIN procedures_icd ON admissions.hadm_id = procedures_icd.subject_idJOIN d_icd_procedures ON procedures_icd.icd_code = d_icd_procedures.icd_codeWHERE patients.subject_id = 10007818  AND EXTRACT(YEAR              FROM admissions.dischtime) = EXTRACT(YEAR                                                   FROM CURRENT_DATE)ORDER BY d_icd_procedures.long_title DESCLIMIT 1
# Count is  53
# 1b49fcb3998703d3dd37e81e:SELECT AVG(c.cost) AS average_costFROM cost cJOIN procedures_icd p ON c.event_id = p.row_idWHERE p.long_title ILIKE '%other%incision%of%pleura%'
# Count is  54
# fd884f642b26768cc1d7cecf:SELECT  (SELECT MAX(s.stay_id)   FROM icustays s   WHERE s.subject_id = 10006053) AS max_stay_id,  (SELECT (s.outtime - s.intime) AS length_of_stay   FROM icustays s   WHERE s.stay_id = max_stay_id) AS length_of_stay
# Count is  55
# 8e96be7df6dd4cc4c1e2a3b4:SELECT MIN(p.weight) AS min_weightFROM patients pJOIN admissions a ON p.subject_id = a.subject_idWHERE p.subject_id = 10031757
# Count is  56
# 85c3e2700b75549e5f889cf1:null
# Count is  57
# 770cb760820f25921dc8ac4a:SELECT SUM(c.cost) AS total_costFROM cost cJOIN d_labitems l ON c.event_id = l.itemidWHERE l.label ILIKE '%thyroxine%t4%'  AND c.event_type = 'lab'
# Count is  58
# 939af21d46d24ad0b2940264:null
# Count is  59
# a2eafdd2283b9391264166aa:WITH last_systolic AS  (SELECT MAX(labevents.valuenum) AS last_systolic   FROM labevents   JOIN admissions ON labevents.hadm_id = admissions.hadm_id   WHERE admissions.subject_id = 10018423     AND labevents.itemid = 10018423     AND admissions.dischtime IS NOT NULL),     first_systolic AS  (SELECT MIN(labevents.valuenum) AS first_systolic   FROM labevents   JOIN admissions ON labevents.hadm_id = admissions.hadm_id   WHERE admissions.subject_id = 10018423     AND labevents.itemid = 10018423     AND admissions.admittime IS NOT NULL)SELECT (last_systolic.last_systolic - first_systolic.first_systolic) AS change_in_systolicFROM last_systolic,     first_systolic
# Count is  60
# bc8d116f59e4fd75687ea181:SELECT p.drugFROM prescriptions pWHERE p.subject_id = 10004733  AND p.starttime >= (CURRENT_DATE - INTERVAL '1 day')  AND p.starttime < CURRENT_DATEORDER BY p.starttime NULLS LAST
# Count is  61
# 1d673cb43fa93e2f43969f21:null
# Count is  62
# 376ce2f69b8cda44c3960e60:SELECT d_labitems.label,       COUNT(*) AS COUNTFROM labeventsJOIN d_labitems ON labevents.itemid = d_labitems.itemidGROUP BY d_labitems.labelORDER BY COUNT DESCLIMIT 3
# Count is  63
# ed31b107608f8a15bae7aa15:null
# Count is  64
# 73e1216fd32c02f0a88adb7b:SELECT COUNT(DISTINCT p.subject_id) AS patient_countFROM patients pJOIN prescriptions pr ON p.subject_id = pr.subject_idJOIN diagnoses_icd d ON p.subject_id = d.subject_idWHERE pr.drug ilike '%metronidazole%'  AND d.icd_code ilike '%urinary%tract%infection%'  AND d.charttime >= (CURRENT_DATE - INTERVAL '1 year')  AND (pr.starttime - d.charttime) <= INTERVAL '2 months'
# Count is  65
# a0cc19360d682b011b5a7c9e:SELECT SUM(c.cost) AS total_costFROM cost cJOIN admissions a ON c.hadm_id = a.hadm_idWHERE a.subject_id = 10021118  AND EXTRACT(YEAR              FROM c.chargetime) >= 2021
# Count is  66
# eb20ba71a6257201e3668689:null
# Count is  67
# 916c297dfa63e76557d57bb8:null
# Count is  68
# c410ac2d5f173d57d86ff06c:null
# Count is  69
# e134d64a96cc7940427b44cf:null
# Count is  70
# 6862d30d896fae9a1cf25fa5:SELECT MAX(c.cost) AS max_total_costFROM cost cJOIN prescriptions p ON c.event_id = p.row_idWHERE p.drug ILIKE '%fenofibrate%'  AND EXTRACT(YEAR              FROM c.chargetime) >= 2021
# Count is  71
# 24e8b0de7b09f21ab851e0c7:null
# Count is  72
# 8de87b88f6cd77d22fb75b7a:SELECT  (SELECT MAX(a.dischtime)   FROM admissions a   WHERE a.subject_id = 10021487     AND a.dischtime < CURRENT_TIMESTAMP()) -  (SELECT MIN(a.admittime)   FROM admissions a   WHERE a.subject_id = 10021487     AND a.admittime <= CURRENT_TIMESTAMP()) AS hours_since_first_diagnosis
# Count is  73
# 633d7843ff15021b4c6b6ac9:SELECT a.marital_statusFROM admissions aWHERE a.subject_id = 10012853ORDER BY a.dischtime DESCLIMIT 1
# Count is  74
# b96e8ac58176933b9e0ee2b3:SELECT m.test_name,       COUNT(*) AS COUNTFROM microbiologyevents mJOIN  (SELECT subject_id   FROM diagnoses_icd   WHERE icd_code IN ('unarmed fight',                      'brawl')) AS d ON m.subject_id = d.subject_idWHERE m.charttime >= (CURRENT_DATE - INTERVAL '2 months')GROUP BY m.test_nameORDER BY COUNT DESCLIMIT 5
# Count is  75
# f6f7ea6d73b8b83013dc2f03:SELECT p.subject_id,       p.hadm_id,       p.icustay_id,       d.dischtime,       p.dischtime - d.dischtime AS lead_time,       pr.procedure_name,       row_number() OVER(PARTITION BY p.subject_id                         ORDER BY p.dischtime - d.dischtime DESC) AS lead_rankFROM patients pJOIN procedures_icd pr ON p.hadm_id = pr.subject_idJOIN admissions d ON p.hadm_id = d.hadm_idWHERE p.hadm_id IN    (SELECT hadm_id     FROM patients     WHERE EXTRACT(YEAR                   FROM dob) = EXTRACT(YEAR                                       FROM CURRENT_DATE)       AND icustay_id IN         (SELECT icustay_id          FROM patients          WHERE EXTRACT(MONTH                        FROM admission_date) = EXTRACT(MONTH                                                       FROM CURRENT_DATE)            AND EXTRACT(YEAR                        FROM admission_date) = EXTRACT(YEAR                                                       FROM CURRENT_DATE)            AND procedure_name = 'percutaneous abdominal drainage'))ORDER BY lead_rank
# Count is  76
# 02641abbf2e5bcb72ad7aedc:SELECT m.test_name,       COUNT(*) AS COUNTFROM microbiologyevents mGROUP BY m.test_nameORDER BY COUNT DESCLIMIT 5
# Count is  77
# e94fc44f50cb46d93aaa3008:SELECT d_icd_diagnoses.icd_code,       d_icd_diagnoses.long_title,       COUNT(*) AS frequencyFROM d_icd_diagnosesJOIN diagnoses_icd ON d_icd_diagnoses.icd_code = diagnoses_icd.icd_codeWHERE d_icd_diagnoses.icd_code::DATE >= '2021-01-01'GROUP BY d_icd_diagnoses.icd_code,         d_icd_diagnoses.long_titleORDER BY frequency DESCLIMIT 5
# Count is  78
# 86741d2d640a5dbbfa5d1036:SELECT MAX(le.valuenum) AS last_valueFROM labevents leJOIN admissions a ON le.hadm_id = a.hadm_idWHERE a.subject_id = 10010471  AND EXTRACT(MONTH              FROM le.charttime) = 5  AND EXTRACT(YEAR              FROM le.charttime) = EXTRACT(YEAR                                           FROM CURRENT_DATE)
# Count is  79
# 0bef44d46b407af716e48911:SELECT  (SELECT     (SELECT valuenum      FROM labevents      WHERE subject_id = 10018328        AND charttime = '2021-05-15 14:00:00') -     (SELECT valuenum      FROM labevents      WHERE subject_id = 10018328        AND charttime = '2021-05-15 13:00:00')) AS difference
# Count is  80
# 59d98dcbea98f9f9a4f33d08:SELECT MAX(i.charttime) AS last_input_timeFROM inputevents iJOIN patients p ON i.subject_id = p.subject_idWHERE p.subject_id = 10013049  AND i.charttime >= '2021-04-09'
# Count is  81
# 3813f972b07ceee5031bb452:null
# Count is  82
# aef4b8676c07216d65074512:SELECT CURRENT_DATE - MAX(m.charttime) AS days_passedFROM labevents mJOIN patients p ON m.subject_id = p.subject_idWHERE p.subject_id = 10018081  AND m.itemid IN    (SELECT itemid     FROM d_labitems     WHERE label ilike '%osmolality%urine%laboratory%test%')
# Count is  83
# 89fa29a6a2fb6b1fff321ece:null
# Count is  84
# 6938557cc42ba52caf388bef:SELECT SUM(i.amount) AS total_amountFROM inputevents iJOIN patients p ON i.subject_id = p.subject_idWHERE p.subject_id = 10005909  AND i.starttime >= '2021-02-12'
# Count is  85
# 1876fa0cb08f316f3b279b75:null
# Count is  86
# 7e045377b0d1df894941da65:SELECT p.drugFROM prescriptions pWHERE p.subject_id = 10021312GROUP BY p.drugHAVING COUNT(p.drug) >= 2
# Count is  87
# 6c16600578aa6d76931a6d00:SELECT m.spec_type_desc,       COUNT(*) AS frequencyFROM microbiologyevents mJOIN admissions a ON m.hadm_id = a.hadm_idJOIN patients p ON a.subject_id = p.subject_idWHERE m.test_name = 'Extirpation of matter from left lower lung lobe'  AND m.org_name = 'Via natural or artificial opening endoscopic'  AND EXTRACT(MONTH              FROM a.admittime) = EXTRACT(MONTH                                          FROM m.charttime)  AND EXTRACT(YEAR              FROM a.admittime) = 2100GROUP BY m.spec_type_descORDER BY frequency DESCLIMIT 5
# Count is  88
# a31f58941f5dbcaed03ddbc3:null
# Count is  89
# 105c5b90ad1c402ff786e8bc:SELECT SUM(c.cost) AS total_costFROM cost cJOIN prescriptions p ON c.event_id = p.row_idWHERE p.drug ILIKE '%ferrous%sulfate%liquid%'
# Count is  90
# e2e9e3d582524db3f2e7d55a:SELECT p.drugFROM prescriptions pWHERE p.subject_id = 10005817  AND p.route = 'nu'ORDER BY p.starttime DESCLIMIT 1
# Count is  91
# 7b18e66852f4386ce57b39c1:null
# Count is  92
# 04f2923c808564e420f2e7be:SELECT MAX(p.starttime) AS last_prescription_timeFROM prescriptions pWHERE p.subject_id = 10037861  AND EXTRACT(MONTH              FROM p.starttime) = 10  AND EXTRACT(YEAR              FROM p.starttime) = EXTRACT(YEAR                                          FROM CURRENT_DATE)  AND p.drug ILIKE '%5%dextrose%'  AND p.drug ILIKE '%pantoprazole%'
# Count is  93
# 081a0e4a4a580c6c981d354c:null
# Count is  94
# b486ef7ac176fc054cfa98dd:SELECT MIN(a.dischtime) AS earliest_discharge_timeFROM admissions aWHERE a.subject_id = 10023117  AND a.dischtime > '2021-01-01'
# Count is  95
# eb33e90dbcfbca0c0e049512:SELECT COUNT(DISTINCT p.subject_id) AS patient_countFROM patients pJOIN admissions a ON p.subject_id = a.subject_idJOIN diagnoses_icd d ON a.hadm_id = d.hadm_idJOIN procedures_icd pr ON a.hadm_id = pr.hadm_idWHERE EXTRACT(YEAR              FROM a.admittime) >= 2021  AND pr.icd_code = '47001'  AND d.icd_code = '47001'  AND EXTRACT(MONTH              FROM a.admittime) = EXTRACT(MONTH                                          FROM d.charttime) - 1
# Count is  96
# 3b514d758ae102351dec4dde:null
# Count is  97
# e812406c3bfd789c61094039:SELECT COUNT(DISTINCT a.subject_id) AS patient_countFROM admissions aWHERE a.dischtime >= (CURRENT_DATE - INTERVAL '1 year')
# Count is  98
# fdf5fc622de2b8d98e233ad6:SELECT p.drugFROM prescriptions pWHERE p.subject_id = 10020740  AND EXTRACT(MONTH              FROM p.starttime) = 5  AND EXTRACT(YEAR              FROM p.starttime) = 2021ORDER BY p.starttime ASCLIMIT 1
# Count is  99
# c814a79881c8be3a4809fdb9:SELECT date_trunc('month', c.charttime) AS MONTH,       MIN(p.weight) AS min_weightFROM patients pJOIN chartevents c ON p.subject_id = c.subject_idWHERE date_part('year', c.charttime) = 2021  AND p.subject_id = 10018423GROUP BY MONTHORDER BY MONTH
# Count is  100
# bbcb03fc3471db9511c31648:SELECT SUM(i.amount) AS total_inputsFROM inputevents iJOIN patients p ON i.subject_id = p.subject_idWHERE p.subject_id = 10018845  AND i.charttime >= '2021-03-27'
# Count is  101
# 1cb7346d2299d0467b9fcb27:null
# Count is  102
# 919f039cb4f4fe92f49e7c86:SELECT COUNT(*)FROM patients pJOIN admissions a ON p.subject_id = a.subject_idWHERE EXTRACT(YEAR              FROM AGE(p.dob)) BETWEEN 20 AND 29
# Count is  103
# 1a61783738e4d38f7694a450:SELECT m.test_name,       m.org_nameFROM microbiologyevents mJOIN patients p ON m.subject_id = p.subject_idWHERE p.subject_id = 7698  AND m.org_name != 'My Department'
# Count is  104
# dddc1e74733a55f7407289ad:SELECT d.icd_code,       COUNT(*) AS frequencyFROM diagnoses_icd dJOIN labevents l ON d.row_id = l.event_idWHERE d.icd_code ilike '%dyskinesia%esophagus%'  AND l.charttime >= (CURRENT_DATE - INTERVAL '1 year')GROUP BY d.icd_codeORDER BY frequency DESCLIMIT 5
# Count is  105
# f3b876d4c257e4b4bc897442:SELECT EXTRACT(YEAR               FROM i.charttime) AS YEAR,       MAX(i.amount) AS max_inputFROM inputevents iJOIN patients p ON i.subject_id = p.subject_idWHERE p.subject_id = 10016810  AND i.itemid = 10016810  AND i.charttime >= '2021-07-02'GROUP BY YEARORDER BY YEAR
# Count is  106
# 5da6b605b949e3c4c068537e:SELECT MIN(m.charttime) AS first_mrsa_testFROM microbiologyevents mJOIN patients p ON m.subject_id = p.subject_idWHERE p.subject_id = 10039831  AND EXTRACT(MONTH              FROM m.charttime) = 12  AND EXTRACT(YEAR              FROM m.charttime) = 2021
# Count is  107
# e0693814cc896b83b3416d2d:null
# Count is  108
# fbcd4d482ef4b1adc5b26de8:null
# Count is  109
# ff935574170a15f329581c0e:SELECT d_icd_procedures.long_title,       COUNT(*) AS procedure_countFROM patientsJOIN admissions ON patients.subject_id = admissions.subject_idJOIN d_icd_procedures ON admissions.hadm_id = d_icd_procedures.row_idWHERE EXTRACT(YEAR              FROM patients.dob) = 1940  AND EXTRACT(YEAR              FROM admissions.admittime) = 2010  AND EXTRACT(YEAR              FROM admissions.dischtime) = 2010  AND admissions.age = 40GROUP BY d_icd_procedures.long_titleORDER BY procedure_count DESCLIMIT 3
# Count is  110
# 1c45da439e97eae264e4d7ce:SELECT SUM(c.cost) AS total_costFROM cost cJOIN prescriptions p ON c.event_id = p.row_idWHERE p.drug ILIKE '%warfarin%'
# Count is  111
# 54b62111b52beeb031b293c2:WITH yesterday_prescriptions AS  (SELECT prescriptions.drug   FROM prescriptions   JOIN patients ON prescriptions.subject_id = patients.subject_id   WHERE patients.subject_id = 10018081     AND EXTRACT(DAY                 FROM prescriptions.starttime) = EXTRACT(DAY                                                         FROM CURRENT_DATE - INTERVAL '1 day')),     today_prescriptions AS  (SELECT prescriptions.drug   FROM prescriptions   JOIN patients ON prescriptions.subject_id = patients.subject_id   WHERE patients.subject_id = 10018081     AND EXTRACT(DAY                 FROM prescriptions.starttime) = EXTRACT(DAY                                                         FROM CURRENT_DATE))SELECT today_prescriptions.drugFROM today_prescriptionsLEFT JOIN yesterday_prescriptions ON today_prescriptions.drug = yesterday_prescriptions.drugWHERE yesterday_prescriptions.drug IS NULL
# Count is  112
# e99de7acd526ced8910358e1:null
# Count is  113
# 503c1a271385c7a9c485a82a:SELECT d_icd_procedures.icd_code,       COUNT(*) AS procedure_countFROM d_icd_proceduresJOIN procedures_icd ON d_icd_procedures.icd_code = procedures_icd.icd_codeWHERE procedures_icd.charttime >= (CURRENT_DATE - INTERVAL '1 year')GROUP BY d_icd_procedures.icd_codeORDER BY procedure_count DESCLIMIT 4
# Count is  114
# 025c400c41ad7c9b0b92dc06:SELECT COUNT(*)FROM prescriptions pWHERE p.subject_id = 10007818  AND p.drug ILIKE '%glucerna%1.5%full%'  AND p.starttime IN    (SELECT MIN(p.starttime)     FROM prescriptions p     WHERE p.subject_id = 10007818       AND p.drug ILIKE '%glucerna%1.5%full%')
# Count is  115
# 348003c7aa52c565e172ee81:SELECT (CURRENT_TIME - MAX(a.dischtime))/3600 AS hours_since_last_stayFROM admissions aJOIN icustays i ON a.hadm_id = i.stay_idWHERE a.subject_id = 10004733  AND i.first_careunit = 'neurology'
# Count is  116
# 6e19826cc8478fa8a97d1dee:SELECT MIN(c.charttime) AS first_timeFROM cost cJOIN prescriptions p ON c.event_id = p.row_idWHERE c.event_type = 'Prescribe'  AND p.drug = 'tobramycin'  AND p.subject_id = 10007818  AND EXTRACT(MONTH              FROM c.charttime) = 7  AND EXTRACT(YEAR              FROM c.charttime) = EXTRACT(YEAR                                          FROM CURRENT_DATE)
# Count is  117
# f5d1341aa772a131aa8ee445:SELECT COUNT(DISTINCT p.subject_id)FROM patients pJOIN diagnoses_icd d ON p.subject_id = d.subject_idWHERE d.icd_code = 'C34.9'  AND EXTRACT(YEAR              FROM p.dob) = 2010
# Count is  118
# 83c8da4296018b701b0ac44b:SELECT i.last_careunitFROM icustays iWHERE i.subject_id = 10007928ORDER BY i.intime DESCLIMIT 1
# Count is  119
# d50f340e88f09cf2749021b3:SELECT d_labitems.label,       COUNT(*) AS COUNTFROM labeventsJOIN d_labitems ON labevents.itemid = d_labitems.itemidJOIN diagnoses_icd ON labevents.hadm_id = diagnoses_icd.hadm_idWHERE diagnoses_icd.icd_code = '423'  AND EXTRACT(YEAR              FROM labevents.charttime) = EXTRACT(YEAR                                                  FROM CURRENT_DATE)GROUP BY d_labitems.labelORDER BY COUNT DESCLIMIT 3
# Count is  120
# 45419a10d80abe89bf6669c5:null
# Count is  121
# 202ecadc0d16d2f85f8ad189:SELECT date_trunc('month', i.charttime) AS MONTH,       MAX(i.amount) AS max_dextrose_5_percent_inputFROM inputevents iJOIN admissions a ON i.hadm_id = a.hadm_idWHERE i.subject_id = 10009035  AND i.itemid IN    (SELECT itemid     FROM d_items     WHERE label = 'Dextrose 5%')GROUP BY MONTHORDER BY MONTH
# Count is  122
# 301ae55bf7f25fd564f985aa:SELECT p.drug,       COUNT(*) AS COUNTFROM patients pJOIN admissions a ON p.subject_id = a.subject_idJOIN diagnoses_icd d ON a.hadm_id = d.hadm_idJOIN prescriptions pr ON a.hadm_id = pr.hadm_idWHERE p.age >= 40  AND d.icd_code = '111'  AND pr.starttime <= (CURRENT_TIMESTAMP() - INTERVAL '2 months')GROUP BY p.drugORDER BY COUNT DESCLIMIT 5
# Count is  123
# e1f82dce913d0a344d686dcb:SELECT SUM(o.value) AS total_mediastinal_outputFROM outputevents oJOIN admissions a ON o.hadm_id = a.hadm_idWHERE a.subject_id = 10005817  AND o.itemid IN    (SELECT itemid     FROM d_items     WHERE linksto = 'mediastinal output')
# Count is  124
# 48b62fcb80cf1fee53b8bfb1:SELECT SUM(i.amount) AS total_inputFROM inputevents iJOIN admissions a ON i.hadm_id = a.hadm_idWHERE a.subject_id = 10018081  AND a.stay_id IN    (SELECT stay_id     FROM icustays     WHERE first_careunit = 'ICU')
# Count is  125
# 0b01e88a1ff2627ccad33628:SELECT COUNT(a.hadm_id) AS number_of_admissionsFROM admissions aJOIN patients p ON a.subject_id = p.subject_idWHERE p.subject_id = 10014729  AND EXTRACT(YEAR              FROM a.admittime) = 2021
# Count is  126
# 75ad421a0a5e3e4d0b60dc18:null
# Count is  127
# ac0594e7c1c0b61c1072e703:SELECT oe.itemid,       COUNT(*) AS event_countFROM outputevents oeWHERE oe.charttime >= '2021-01-01'GROUP BY oe.itemidORDER BY event_count DESCLIMIT 5
# Count is  128
# a999623358b249c2ff668390:SELECT COUNT(*)FROM patients pJOIN admissions a ON p.subject_id = a.subject_idWHERE a.dod IS NULL  AND a.age >= 60
# Count is  129
# 426ce736177896950ecec77f:SELECT MIN(p.dischtime) AS earliest_discharge_timeFROM patients pJOIN admissions a ON p.subject_id = a.subject_idJOIN procedures_icd pi ON a.hadm_id = pi.hadm_idWHERE p.subject_id = 10038933  AND (pi.icd_code ilike '%lung%'       OR pi.icd_code ilike '%bronchus%')
# Count is  130
# 3b5047dc23a01179caf1728d:SELECT m.org_nameFROM microbiologyevents mGROUP BY m.org_nameORDER BY COUNT(m.org_name) DESCLIMIT 1
# Count is  131
# 82623a9f149ae4a941d737fc:SELECT d.long_title AS diagnosis_nameFROM patients pJOIN admissions a ON p.subject_id = a.subject_idJOIN diagnoses_icd d ON a.hadm_id = d.hadm_idWHERE p.subject_id = 10006580ORDER BY a.dischtime DESCLIMIT 1
# Count is  132
# 62024a7f34e319d9ef55142b:null
# Count is  133
# 7d5fe035bb44c9237b17dfe5:null
# Count is  134
# 15b35d75bfa2fee08c48a6c6:SELECT MAX(a.charttime) AS last_time_patient_had_max_respiratory_rateFROM admissions aJOIN  (SELECT MAX(valuenum) AS max_respiratory_rate   FROM labevents   WHERE itemid = 10011398     AND charttime >= (CURRENT_DATE - INTERVAL '114 days')) AS mr ON TRUEWHERE a.subject_id = 10011398  AND a.charttime <= mr.max_respiratory_rate
# Count is  135
# df3f8f6e1b9b51fba40fb909:null
# Count is  136
# c5d97a3fa6b67acc42a60f3f:SELECT (CURRENT_DATE - MAX(a.dischtime)) AS days_since_dischargeFROM admissions aJOIN icustays i ON a.hadm_id = i.hadm_idWHERE a.subject_id = 10039831  AND i.last_careunit = 'discharge lounge'
# Count is  137
# 5f0f9e0915ce37a5ce452e00:SELECT p.subject_id,       p.full_name,       COUNT(*) AS test_countFROM microbiologyevents mJOIN patients p ON m.subject_id = p.subject_idWHERE EXTRACT(YEAR              FROM m.charttime) = EXTRACT(YEAR                                          FROM CURRENT_DATE)  AND m.test_name ILIKE '%hematology%'GROUP BY p.subject_id,         p.full_nameORDER BY test_count DESCLIMIT 5
# Count is  138
# 03697a77b237d131d11e6b7c:null
# Count is  139
# 09e77a973741f315e0526f82:SELECT oe.itemid,       COUNT(*) AS COUNTFROM outputevents oeWHERE oe.charttime >= (CURRENT_DATE - INTERVAL '1 year')GROUP BY oe.itemidORDER BY COUNT DESCLIMIT 4
# Count is  140
# 00ddca0abfcd2315f0c91ce6:SELECT m.spec_type_desc,       COUNT(*) AS frequencyFROM microbiologyevents mJOIN  (SELECT s.subject_id,          s.hadm_id   FROM patients s   JOIN admissions a ON s.subject_id = a.subject_id   WHERE a.admission_type_code = 'E'     AND a.discharge_location = 'ANP') AS p ON m.subject_id = p.subject_idGROUP BY m.spec_type_descORDER BY frequency DESCLIMIT 3
# Count is  141
# 37833afd75b9cf71f8d0ed01:SELECT EXTRACT(YEAR               FROM p.dob) AS YEARFROM patients pWHERE p.dod IS NULL  AND p.gender = 'M'  AND p.affiliation = 'def jam records'ORDER BY YEAR NULLS LASTLIMIT 1
# Count is  142
# e57e3f80e3cc0a3b1a3c509c:SELECT COUNT(DISTINCT p.subject_id) AS number_of_patientsFROM patients pJOIN admissions a ON p.subject_id = a.subject_idJOIN procedures_icd pi ON a.hadm_id = pi.hadm_idJOIN d_icd_procedures d ON pi.icd_code = d.icd_codeWHERE EXTRACT(YEAR              FROM a.admittime) = 2021  AND d.long_title ILIKE '%radical%excision%of%other%lymph%nodes%'  AND a.admission_location = 'same hospital'  AND a.dischtime IS NOT NULL  AND (a.dischtime - a.admittime) <= 72
# Count is  143
# c60ed59c6b7df6bf5fbfa0cf:SELECT  (SELECT MIN(labevents.charttime)   FROM labevents   WHERE labevents.subject_id = 10004733     AND labevents.itemid =       (SELECT itemid        FROM d_labitems        WHERE label = 'Albumin')) -  (SELECT MIN(admissions.admittime)   FROM admissions   WHERE admissions.subject_id = 10004733) AS hours_passed
# Count is  144
# ec89baea1f34f1904eed2a70:SELECT p.drug,       COUNT(*) AS COUNTFROM prescriptions pWHERE p.drug ilike '%potassium%chl%40%meq%/1000%ml%ns%'  AND p.starttime >= (CURRENT_DATE - INTERVAL '1 year')GROUP BY p.drugORDER BY COUNT DESCLIMIT 4
# Count is  145
# 78e5fca5ff0661c021019cac:SELECT p.drug,       COUNT(*) AS num_prescriptionsFROM prescriptions pWHERE p.subject_id = 10009049  AND p.starttime >= '2021-05-01'GROUP BY p.drugHAVING COUNT(p.drug) >= 2
# Count is  146
# 48859a4418a3875bf6082407:SELECT SUM(labevents.valuenum) AS total_bilirubinFROM patientsJOIN admissions ON patients.subject_id = admissions.subject_idJOIN labevents ON admissions.hadm_id = labevents.hadm_idWHERE patients.subject_id = 10005866  AND EXTRACT(MONTH              FROM labevents.charttime) = 3  AND EXTRACT(YEAR              FROM labevents.charttime) = 2010
# Count is  147
# 3c3a60ef6ea248ad69d36deb:SELECT MAX(p.starttime) AS last_prescription_dateFROM prescriptions pWHERE p.subject_id = 10008287  AND p.route = 'pr'  AND p.starttime >= '2008-08-01'
# Count is  148
# c486d3f623a7c682d0051190:null
# Count is  149
# 9e71c9503ead8f262e901ec1:SELECT MIN(p.starttime) AS first_prescription_timeFROM prescriptions pWHERE p.subject_id = 10005348  AND p.drug ILIKE '%docusate%sodium%'  AND p.drug ILIKE '%dorzolamide%2%/timolol%0.5%ophth%'
# Count is  150
# 5ff41378c47dc43f9ea36aa9:SELECT SUM(cost.cost) AS total_costFROM patientsJOIN admissions ON patients.subject_id = admissions.subject_idJOIN cost ON admissions.hadm_id = cost.hadm_idWHERE patients.subject_id = 10008454  AND cost.event_type = 'packed red blood cells'  AND cost.event_id IN    (SELECT icustays.stay_id     FROM icustays     WHERE icustays.subject_id = 10008454       AND icustays.first_careunit IS NOT NULL)
# Count is  151
# f64502ea7695fae28227dfce:null
# Count is  152
# 7437f40a03312a89a951bf71:SELECT p.subject_id,       p.hadm_id,       m.test_name,       m.org_name,       COUNT(*) AS test_countFROM patients pJOIN admissions a ON p.subject_id = a.subject_idJOIN microbiologyevents m ON a.hadm_id = m.hadm_idWHERE p.hadm_id IN    (SELECT hadm_id     FROM admissions     WHERE procedure_id IN         (SELECT procedure_id          FROM procedures_icd          WHERE icd_code = '625550'))GROUP BY p.subject_id,         p.hadm_id,         m.test_name,         m.org_nameORDER BY test_count DESCLIMIT 4
# Count is  153
# 9ed380731316b97f5b4cc772:SELECT COUNT(DISTINCT p.subject_id) AS patient_countFROM patients pJOIN diagnoses_icd d ON p.subject_id = d.subject_idJOIN labevents l ON d.hadm_id = l.hadm_idWHERE d.icd_code = '454.0'  AND EXTRACT(YEAR              FROM p.dob) = 2021  AND l.itemid IN    (SELECT itemid     FROM d_labitems     WHERE label ilike '%blood%in%stool%')  AND l.charttime BETWEEN d.charttime AND d.charttime + interval '2 months'
# Count is  154
# 71b23a88bad2ea2f52f12b02:SELECT p.drug,       COUNT(*) AS COUNTFROM prescriptions pWHERE p.drug ilike '%phenytoin%infatab%'  AND EXTRACT(YEAR              FROM p.starttime) = 2021GROUP BY p.drugORDER BY COUNT DESCLIMIT 5
# Count is  155
# 6375d8b399f74f248505155f:SELECT COUNT(DISTINCT p.row_id) AS num_proceduresFROM patients pJOIN procedures_icd pi ON p.subject_id = pi.subject_idWHERE p.subject_id = 10021487  AND pi.icd_code = '12345'
# Count is  156
# 59e57b904fb229550751564d:SELECT AVG(COUNT) AS average_patientsFROM  (SELECT COUNT(*) AS COUNT   FROM patients p   JOIN admissions a ON p.subject_id = a.subject_id   JOIN diagnoses_icd d ON a.hadm_id = d.hadm_id   WHERE EXTRACT(YEAR                 FROM a.admittime) = 2010     AND d.icd_code IN ('I10-I12',                        'I20-I24',                        'I30-I34',                        'I40-I44',                        'I50-I54',                        'I60-I64',                        'I70-I74',                        'I80-I84',                        'I90-I94')   GROUP BY DATE(a.admittime)) AS subquery
# Count is  157
# 76a3b26583f61cc00377b6a2:SELECT COUNT(DISTINCT p.drug) AS num_drugsFROM prescriptions pWHERE p.subject_id = 10004720  AND EXTRACT(MONTH              FROM p.starttime) = 4  AND EXTRACT(YEAR              FROM p.starttime) = 2021
# Count is  158
# a735a4a7dda21a510947e2e4:null
# Count is  159
# 4e04be3ade7631c7f953c6b5:SELECT m.test_name,       COUNT(*) AS test_countFROM microbiologyevents mWHERE EXTRACT(YEAR              FROM m.charttime) = EXTRACT(YEAR                                          FROM CURRENT_DATE)GROUP BY m.test_nameORDER BY test_count DESCLIMIT 4
# Count is  160
# 45384727303e9e1f25c170a6:null
# Count is  161
# ac9de4303d9e69514c759992:SELECT m.org_nameFROM microbiologyevents mWHERE m.subject_id = 10038081ORDER BY m.charttime DESCLIMIT 1
# Count is  162
# 0fae80f812674773157d9f2a:SELECT p.genderFROM patients pWHERE p.subject_id = 10022880
# Count is  163
# 55712c5df13d0dbf402229f5:SELECT o.valueFROM outputevents oJOIN patients p ON o.subject_id = p.subject_idWHERE p.subject_id = 10019917  AND o.charttime >= '2021-01-19'ORDER BY o.charttime ASCLIMIT 1
# Count is  164
# 11ee027a4849b568c91b8cfe:SELECT m.test_name,       COUNT(*) AS test_countFROM microbiologyevents mWHERE m.charttime >= (CURRENT_DATE - INTERVAL '1 year')GROUP BY m.test_nameORDER BY test_count DESCLIMIT 5
# Count is  165
# 3f777e85538090faa2446aeb:SELECT m.org_name,       COUNT(*) AS specimen_countFROM microbiologyevents mJOIN  (SELECT subject_id,          hadm_id   FROM diagnoses_icd   WHERE icd_code = '111'     AND charttime >= (CURRENT_DATE - INTERVAL '1 year') ) AS d ON m.subject_id = d.subject_idAND m.hadm_id = d.hadm_idJOIN  (SELECT subject_id,          hadm_id   FROM admissions   WHERE admission_type = 'Intestinal infection'     AND admission_location = 'Same hospital' ) AS a ON m.subject_id = a.subject_idAND m.hadm_id = a.hadm_idWHERE m.org_name not ilike '%elsewhere%classified%'GROUP BY m.org_nameORDER BY specimen_count DESCLIMIT 5
# Count is  166
# ea540b00c584340b05707e3c:SELECT m.test_name,       m.org_nameFROM microbiologyevents mJOIN patients p ON m.subject_id = p.subject_idWHERE p.subject_id = 57050  AND m.org_name != 'My Department'
# Count is  167
# bb5e3f49dbcb908901443bf7:null
# Count is  168
# 3f83bca7c25ce27ab09a7ef0:WITH last_admission AS  (SELECT a.subject_id,          a.hadm_id,          a.charttime,          lag(a.charttime) OVER (PARTITION BY a.subject_id                                 ORDER BY a.charttime) AS previous_admission_time   FROM admissions a   WHERE a.subject_id = 10003046     AND a.charttime IS NOT NULL),     last_weight AS  (SELECT l.subject_id,          l.hadm_id,          l.charttime,          l.valuenum AS last_weight,          lag(l.valuenum) OVER (PARTITION BY l.subject_id                                ORDER BY l.charttime) AS previous_weight   FROM labevents l   JOIN last_admission la ON l.hadm_id = la.hadm_id   AND l.charttime = la.previous_admission_time   WHERE l.subject_id = 10003046     AND l.valuenum IS NOT NULL)SELECT (MAX(lw.last_weight) - MIN(lw.previous_weight)) AS weight_differenceFROM last_weight lw
# Count is  169
# 94d8481d364db4cbd70b366f:null
# Count is  170
# f08654b0c2c58546d18b7efb:SELECT m.test_nameFROM microbiologyevents mWHERE m.subject_id = 10002428  AND m.charttime >= (CURRENT_DATE - INTERVAL '16 months')ORDER BY m.charttime DESCLIMIT 1
# Count is  171
# 0298d7de83dc23f17441f202:null
# Count is  172
# 5ed395ac8cfadff8f83f1d45:null
# Count is  173
# 94122ab2640e86cea1d8cefe:SELECT p.subject_id,       p.hadm_id,       d.icd_code,       pr.icd_code,       COUNT(*) AS procedure_countFROM patients pJOIN diagnoses_icd d ON p.subject_id = d.subject_idAND p.hadm_id = d.hadm_idJOIN procedures_icd pr ON p.subject_id = pr.subject_idAND p.hadm_id = pr.hadm_idWHERE d.icd_code = 'E1179'GROUP BY p.subject_id,         p.hadm_id,         d.icd_code,         pr.icd_codeORDER BY procedure_count DESCLIMIT 4
# Count is  174
# 197be288d5dde700d2440d8a:null
# Count is  175
# 7ed170e256f209788ad3c985:null
# Count is  176
# c731547cf5d2fc4a71b9d129:SELECT  (SELECT MAX(d.charttime)   FROM diagnoses_icd d   WHERE d.subject_id = 10018081     AND d.icd_code = '440.013') AS last_diagnosis_time,       CURRENT_DATE AS today
# Count is  177
# 3a676bfafee66c27173904e8:null
# Count is  178
# 16023ddab245248aaafeb7c0:null
# Count is  179
# 7dad28b95137a6421d3e7e5e:SELECT d.long_title,       COUNT(*) AS COUNTFROM patients pJOIN admissions a ON p.subject_id = a.subject_idJOIN diagnoses_icd d ON a.hadm_id = d.hadm_idJOIN d_icd_diagnoses d2 ON d.icd_code = d2.icd_codeJOIN patients p2 ON a.subject_id = p2.subject_idWHERE p.gender = 'Female'  AND p2.age >= 65GROUP BY d.long_titleORDER BY COUNT DESCLIMIT 10
# Count is  180
# 411239af52a2ceaa4e79d867:SELECT COUNT(p.drug) AS num_drugsFROM prescriptions pWHERE p.subject_id = 10020944  AND p.starttime >= (CURRENT_DATE - INTERVAL '24 months')
# Count is  181
# 8f037d1cedf499b333e3a25d:SELECT MIN(m.charttime) AS first_microbiology_test_timeFROM microbiologyevents mWHERE m.subject_id = 10015931  AND EXTRACT(MONTH              FROM m.charttime) = EXTRACT(MONTH                                          FROM CURRENT_DATE)  AND EXTRACT(YEAR              FROM m.charttime) = EXTRACT(YEAR                                          FROM CURRENT_DATE)
# Count is  182
# b335cc2faa2de8ffbaba2e95:null
# Count is  183
# 91c770552e4894cdd9ea0079:SELECT COUNT(DISTINCT m.subject_id) AS number_of_patientsFROM microbiologyevents mWHERE EXTRACT(YEAR              FROM m.charttime) = EXTRACT(YEAR                                          FROM CURRENT_DATE)  AND m.test_name ILIKE '%staph%aureus%swab%'
# Count is  184
# 356df71d59db66ac2534a5d3:SELECT COUNT(DISTINCT a.subject_id) AS total_patientsFROM admissions aWHERE a.admittime >= (CURRENT_DATE - INTERVAL '1 year')
# Count is  185
# 264e8e9083e7fe02916af314:SELECT p.drugFROM prescriptions pWHERE p.subject_id = 10025612  AND EXTRACT(MONTH              FROM p.starttime) = 10  AND EXTRACT(YEAR              FROM p.starttime) = EXTRACT(YEAR                                          FROM CURRENT_DATE)ORDER BY p.starttime DESCLIMIT 1
# Count is  186
# 2178992e7accd7fb74726c82:SELECT COUNT(DISTINCT a.subject_id) AS patient_countFROM admissions aJOIN patients p ON a.subject_id = p.subject_idWHERE a.admittime = CURRENT_DATE  AND p.permanent_residency = TRUE
# Count is  187
# 8b765650926782471632323b:null
# Count is  188
# 52015439c33be0dc487387d4:null
# Count is  189
# a75bc1cf0cdc6921d07386f9:SELECT AVG(c.cost) AS average_costFROM prescriptions pJOIN cost c ON p.row_id = c.event_idWHERE p.drug ilike '%heparin%flush%'  AND p.dose_unit_rx = '100 units/ml'
# Count is  190
# 057355cc0961a85bb8801e26:null
# Count is  191
# c189cadcf09e3eb65ff5c31a:SELECT p.drug,       COUNT(*) AS COUNTFROM patients pJOIN prescriptions pr ON p.subject_id = pr.subject_idJOIN admissions a ON p.subject_id = a.subject_idWHERE a.age >= 60GROUP BY p.drugORDER BY COUNT DESCLIMIT 3
# Count is  192
# 6b48b47dea05709d8dddd909:WITH co2_levels AS  (SELECT labevents.subject_id,          SUM(labevents.valuenum) AS total_co2   FROM labevents   JOIN admissions ON labevents.hadm_id = admissions.hadm_id   WHERE labevents.itemid =       (SELECT itemid        FROM d_labitems        WHERE label = 'CO2')   GROUP BY labevents.subject_id)SELECT co2_levels.subject_id,       co2_levels.total_co2FROM co2_levelsJOIN  (SELECT co2_levels.subject_id,          co2_levels.total_co2   FROM co2_levels   ORDER BY co2_levels.total_co2 DESC   LIMIT 2) AS last_two_co2_levels ON co2_levels.subject_id = last_two_co2_levels.subject_idWHERE co2_levels.subject_id = 10038933  AND co2_levels.total_co2 < last_two_co2_levels.total_co2
# Count is  193
# 3c71f198ffca8a3ba108d583:SELECT m.org_nameFROM microbiologyevents mWHERE m.subject_id = 10027602ORDER BY m.charttime ASCLIMIT 1
# Count is  194
# fdc29ef4f59ae676ae12361e:SELECT icustays.intimeFROM icustaysJOIN admissions ON icustays.hadm_id = admissions.hadm_idWHERE icustays.first_careunit ilike '%ICU%'GROUP BY icustays.intimeHAVING COUNT(DISTINCT admissions.hadm_id) < 20ORDER BY icustays.intime NULLS LAST
# Count is  195
# c7d2ebb491c0d6f0d71149a2:SELECT  (SELECT MAX(o.outtime)   FROM transfers o   WHERE o.subject_id = 10031757     AND o.eventtype = 'intensive care unit') -  (SELECT MIN(i.intime)   FROM transfers i   WHERE i.subject_id = 10031757     AND i.eventtype = 'intensive care unit') AS duration
# Count is  196
# 21c6f900462d7a78f5c1ea2f:SELECT p.drug,       SUM(p.dose_val_rx::FLOAT) AS total_doseFROM patients pJOIN prescriptions pr ON p.subject_id = pr.subject_idWHERE p.gender = 'M'  AND EXISTS    (SELECT 1     FROM admissions a     WHERE a.subject_id = p.subject_id       AND a.hadm_id IN         (SELECT hadm_id          FROM icustays))GROUP BY p.drugORDER BY total_dose DESC NULLS LAST
# Count is  197
# e256c7b08d9dde3880221886:SELECT d.icd_code,       d.long_title,       COUNT(*) AS frequencyFROM diagnoses_icd dJOIN  (SELECT subject_id,          icd_code,          charttime   FROM diagnoses_icd   WHERE icd_code IN       (SELECT icd_code        FROM diagnoses_icd        WHERE long_title ilike '%dependence%machines%'          OR long_title ilike '%supplemental%oxygen%')) AS m ON d.subject_id = m.subject_idAND d.icd_code = m.icd_codeAND EXTRACT(MONTH            FROM d.charttime) = EXTRACT(MONTH                                        FROM m.charttime) + 1GROUP BY d.icd_code,         d.long_titleORDER BY frequency DESCLIMIT 3
# Count is  198
# c8da13e1438ff1e420bfe724:SELECT date_trunc('month', p.starttime) AS MONTH,       COUNT(*) AS num_prescriptions,       SUM(c.cost) AS total_costFROM prescriptions pJOIN cost c ON p.row_id = c.event_idWHERE p.drug ILIKE '%antihistamine%'GROUP BY MONTHORDER BY num_prescriptions DESC,         total_cost DESCLIMIT 1
# Count is  199
# 8d2a0e07f81d0db3efed2350:null
# Count is  200
# ...
# Count is  1109
# 6ac4cfa978f125a71ca0e9b0:SELECT SUM(p.dose_val_rx::FLOAT) AS total_doseFROM prescriptions pJOIN patients pt ON p.subject_id = pt.subject_idWHERE pt.subject_id = 10005909  AND p.drug ILIKE '%phenazopyridine%'  AND p.starttime >= '2021-10-01'  AND p.starttime < '2021-11-01'
# Count is  1110
# e5f56337e5fbe51641a80d77:WITH patient_age AS  (SELECT EXTRACT(YEAR                  FROM age(CURRENT_DATE, p.dob)) AS age   FROM patients p   WHERE p.subject_id = 10009628)SELECT percent_rank() OVER (                            ORDER BY l.valuenum) AS percentile_rankFROM labevents lJOIN admissions a ON l.hadm_id = a.hadm_idJOIN patient_age pa ON a.age = pa.ageWHERE l.itemid =    (SELECT itemid     FROM d_labitems     WHERE label = 'Hemoglobin')
# Count is  1111
# 7ed6ef4b97a89c40124bd85f:SELECT COUNT(DISTINCT a.subject_id) AS number_of_patientsFROM admissions aWHERE a.marital_status IS NOT NULL  AND EXTRACT(HOUR              FROM a.admittime) BETWEEN 6 AND 9
# Count is  1112
# 601558b753933c463ad3089a:null
# Count is  1113
# ec1ed057dd7ec2a55f903e6e:SELECT COUNT(*)FROM inputevents iWHERE i.subject_id = 10004235  AND EXTRACT(MONTH              FROM i.charttime) = 12  AND EXTRACT(DAY              FROM i.charttime) = 24  AND EXTRACT(YEAR              FROM i.charttime) = EXTRACT(YEAR                                          FROM CURRENT_DATE) - 1
# Count is  1114
# c2d3722d0ba8692f756e7846:SELECT d.long_titleFROM diagnoses_icd dJOIN  (SELECT MIN(d.row_id) AS min_row_id   FROM diagnoses_icd   WHERE subject_id = 10021666     AND EXTRACT(YEAR                 FROM charttime) = EXTRACT(YEAR                                           FROM CURRENT_DATE) ) AS m ON d.row_id = m.min_row_id
# Count is  1115
# 5a67eba88dd963170a026d15:SELECT p.dose_val_rxFROM prescriptions pWHERE p.drug ILIKE '%glipizide%xl%'  AND p.subject_id = 10029484
# Count is  1116
# a196342dccc0b8df5c23dbb4:SELECT COUNT(DISTINCT p.subject_id) AS total_patientsFROM patients pJOIN diagnoses_icd d ON p.subject_id = d.subject_idJOIN cost c ON d.event_id = c.event_idWHERE d.icd_code IN ('42962',                     '42963')  AND c.cost > 0  AND c.chargetime >= '2021-01-01'  AND (p.dod IS NULL       OR (p.dod - c.chargetime::TIMESTAMP) > interval '30 days')
# Count is  1117
# a4371b693f24038ad04881c2:null
# Count is  1118
# 52f6bc8e9873cce45456c38e:SELECT p.genderFROM patients pWHERE p.subject_id = 10025463
# Count is  1119
# 8465e809028d1263318be90f:WITH first_admission AS  (SELECT a.subject_id,          a.hadm_id,          a.admittime,          lag(le.valuenum) OVER (PARTITION BY a.subject_id                                 ORDER BY le.charttime) AS previous_value   FROM admissions a   JOIN labevents le ON a.hadm_id = le.hadm_id   WHERE a.subject_id = 10009628     AND a.admittime =       (SELECT MIN(admittime)        FROM admissions        WHERE subject_id = 10009628)),     last_admission AS  (SELECT a.subject_id,          a.hadm_id,          a.dischtime,          lead(le.valuenum) OVER (PARTITION BY a.subject_id                                  ORDER BY le.charttime) AS next_value   FROM admissions a   JOIN labevents le ON a.hadm_id = le.hadm_id   WHERE a.subject_id = 10009628     AND a.dischtime =       (SELECT MAX(dischtime)        FROM admissions        WHERE subject_id = 10009628))SELECT  (SELECT next_value   FROM last_admission) -  (SELECT previous_value   FROM first_admission) AS differenceFROM first_admission
# Count is  1120
# ef5e50d5ccd02aaa3b7e4873:WITH patient_age AS  (SELECT p.row_id,          p.subject_id,          EXTRACT(YEAR                  FROM AGE(p.dob)) AS age   FROM patients p   WHERE p.subject_id = 10037975)SELECT percent_rank() OVER (                            ORDER BY l.valuenum) AS percentile_rankFROM labevents lJOIN patient_age pa ON l.subject_id = pa.subject_idWHERE l.itemid =    (SELECT itemid     FROM d_labitems     WHERE label = 'Magnesium')  AND l.valuenum = 2.0  AND pa.age =    (SELECT age     FROM patient_age)
# Count is  1121
# debd4fb35717b39a57ee2bec:SELECT SUM(c.cost) AS total_costFROM cost cJOIN diagnoses_icd d ON c.event_id = d.row_idWHERE d.icd_code = '415071'
# Count is  1122
# 3de4eeab52c93e43309156d7:null
# Count is  1123
# 8394891759bbd70bd4c46e5d:SELECT MIN(c.cost) AS minimum_total_costFROM cost cJOIN diagnoses_icd d ON c.event_id = d.row_idWHERE d.icd_code = 'Malignant neoplasm of intrahepatic bile ducts'
# Count is  1124
# 0552fb2fb3c9ef8054e31fe0:SELECT COUNT(a.hadm_id) AS number_of_admissionsFROM admissions aWHERE a.subject_id = 10005817  AND EXTRACT(YEAR              FROM a.admittime) >= 2021
# Count is  1125
# 17bb906271e8d84bf499f645:WITH last_admission AS  (SELECT a.subject_id,          a.hadm_id,          a.charttime,          lag(a.charttime) OVER (PARTITION BY a.subject_id                                 ORDER BY a.charttime) AS previous_charttime   FROM admissions a   WHERE a.subject_id = 10038999     AND a.charttime IS NOT NULL),     last_labevent AS  (SELECT l.subject_id,          l.hadm_id,          l.charttime,          lag(l.valuenum) OVER (PARTITION BY l.subject_id                                ORDER BY l.charttime) AS previous_valuenum   FROM labevents l   JOIN last_admission la ON l.hadm_id = la.hadm_id   AND l.charttime = la.previous_charttime   WHERE l.subject_id = 10038999     AND l.valuenum IS NOT NULL)SELECT (l.valuenum - l.previous_valuenum) AS change_in_mesothelial_cellsFROM last_labevent lWHERE l.subject_id = 10038999  AND l.previous_valuenum IS NOT NULL
# Count is  1126
# 174eb164f7575dec3a790c67:SELECT p.drug,       COUNT(*) AS frequencyFROM prescriptions pJOIN admissions a ON p.hadm_id = a.hadm_idWHERE EXTRACT(YEAR              FROM a.dischtime) = 2021  AND a.age BETWEEN 40 AND 49GROUP BY p.drugORDER BY frequency DESCLIMIT 4
# Count is  1127
# 32bb1be23959c4c55393389e:SELECT a.insuranceFROM admissions aWHERE a.subject_id = 10035185ORDER BY a.dischtime DESCLIMIT 1
# Count is  1128
# 254b58ea3d513164000b4a51:SELECT MIN(m.charttime) AS first_red_blood_cells_test_timeFROM microbiologyevents mJOIN admissions a ON m.hadm_id = a.hadm_idWHERE m.test_name ILIKE '%red%blood%cells%'  AND a.subject_id = 10035185
# Count is  1129
# a13bd95a1540c1bc4c4568db:SELECT MAX(le.charttime) AS last_ferritin_reading_time,       MAX(le.valuenum) AS last_ferritin_readingFROM labevents leWHERE le.subject_id = 10020740  AND EXTRACT(MONTH              FROM le.charttime) = 3  AND EXTRACT(YEAR              FROM le.charttime) = 2021  AND le.itemid = 757071
# Count is  1130
# 54c7213807ea893bd586bc8a:SELECT p.subject_id,       p.hadm_id,       d.icd_code,       d.long_title,       COUNT(*) AS procedure_countFROM patients pJOIN admissions a ON p.subject_id = a.subject_idJOIN diagnoses_icd d ON a.hadm_id = d.hadm_idWHERE p.hadm_id IN    (SELECT hadm_id     FROM patients     WHERE reposition_left_maxilla = 'yes'       AND external_fixation_device = 'yes'       AND percutaneous_approach = 'yes'       AND EXTRACT(YEAR                   FROM a.admittime) = EXTRACT(YEAR                                               FROM CURRENT_DATE)     GROUP BY hadm_id     HAVING COUNT(DISTINCT d.icd_code) >= 4)GROUP BY p.subject_id,         p.hadm_id,         d.icd_code,         d.long_titleORDER BY procedure_count DESCLIMIT 4
# Count is  1131
# 9d55be8800c23366c5a86393:SELECT COUNT(DISTINCT mp.subject_id) AS patient_countFROM microbiologyevents mpWHERE mp.test_name ILIKE '%bicarbonate%'  AND EXTRACT(YEAR              FROM mp.charttime) = EXTRACT(YEAR                                           FROM CURRENT_DATE) - 1
# Count is  1132
# 45b34eeae5d3c8d44b703194:SELECT SUM(CAST(p.dose_val_rx AS DOUBLE PRECISION)) AS total_doseFROM patients pJOIN prescriptions pr ON p.subject_id = pr.subject_idWHERE p.subject_id = 10007818  AND pr.drug ILIKE '%sodium%liquid%'LIMIT 1
# Count is  1133
# a46311c1dfd74be11feecdf6:SELECT labevents.valuenum AS diastolic_valueFROM patientsJOIN admissions ON patients.subject_id = admissions.subject_idJOIN labevents ON admissions.hadm_id = labevents.hadm_idWHERE patients.subject_id = 10039831  AND labevents.itemid = 15555  AND labevents.charttime >= '2021-12-13'ORDER BY labevents.charttime ASCLIMIT 1
# Count is  1134
# 6538a6e4ef46b71b8a6089ab:null
# Count is  1135
# fed90306e7ed0344ed0a3b7d:null
# Count is  1136
# 11f255bdec2500307cbe317f:null
# Count is  1137
# 0565cd591766fabfa3dec186:SELECT p.drug,       COUNT(*) AS COUNTFROM patients pJOIN prescriptions pr ON p.subject_id = pr.subject_idJOIN admissions a ON p.subject_id = a.subject_idWHERE p.gender = 'f'  AND a.age BETWEEN 20 AND 21  AND a.dischtime >= a.admittime + interval '1 month'  AND pr.drug ilike '%acquired%hypothyroidism%'GROUP BY p.drugORDER BY COUNT DESCLIMIT 3
# Count is  1138
# 8188f6370eb20b529ef916f2:SELECT p.drug,       COUNT(*) AS COUNTFROM prescriptions pWHERE EXTRACT(YEAR              FROM p.starttime) = EXTRACT(YEAR                                          FROM CURRENT_DATE)GROUP BY p.drugORDER BY COUNT DESCLIMIT 5
# Count is  1139
# 6985b7163e6c8b9db7102745:SELECT COUNT(DISTINCT(p.row_id)) AS num_admissionsFROM patients pJOIN admissions a ON p.subject_id = a.subject_idJOIN diagnoses_icd d ON a.hadm_id = d.hadm_idWHERE p.subject_id = 10020740  AND d.icd_code = 'tpn w/ lipids'  AND a.admittime >= '2021-03-07'
# Count is  1140
# 8a0d9ca8816e2d1ca14e3fca:SELECT p.drugFROM prescriptions pWHERE p.subject_id = 10019172  AND EXTRACT(MONTH              FROM p.starttime) = 11  AND EXTRACT(YEAR              FROM p.starttime) = EXTRACT(YEAR                                          FROM CURRENT_DATE)ORDER BY p.starttime DESCLIMIT 1
# Count is  1141
# 3a0be19d3169bb19a1452e68:SELECT EXTRACT(epoch               FROM (now() - MIN(c.charttime)))/3600 AS hours_since_first_diagnosisFROM cost cJOIN diagnoses_icd d ON c.event_id = d.row_idWHERE c.subject_id = 10021487  AND d.icd_code ilike '%intra-abdominal%organs%'  AND d.icd_code not ilike '%open%wound%into%cavity%'  AND d.icd_code not ilike '%peritoneum%'
# Count is  1142
# 5534a345d569cc39211962ae:SELECT COUNT(DISTINCT p.subject_id) AS patient_countFROM patients pJOIN diagnoses_icd d ON p.subject_id = d.subject_idJOIN procedures_icd pr ON d.icd_code = pr.icd_codeWHERE pr.icd_code ilike '%electric%countershock%of%heart%'  AND EXISTS    (SELECT 1     FROM patients pt     WHERE pt.subject_id = p.subject_id       AND pt.had_tobacco_use = TRUE)  AND d.charttime BETWEEN p.admittime AND (p.dischtime + interval '2 months')
# Count is  1143
# 1afade11184c7bc98c9756f8:SELECT MAX(le.charttime) AS last_lab_test_dateFROM labevents leJOIN admissions a ON le.hadm_id = a.hadm_idWHERE a.subject_id = 10005909  AND le.itemid IN    (SELECT itemid     FROM d_labitems     WHERE label ilike '%fibrinogen%functional%')
# Count is  1144
# 11c8c8af342244bb88c103ec:null
# Count is  1145
# 92b8f8b9f70e026d369cdfbd:null
# Count is  1146
# 8b3f8e25e291ddb0d2ad3f7e:SELECT p.dod AS patient_discharge_dateFROM patients pJOIN admissions a ON p.subject_id = a.subject_idWHERE a.admittime BETWEEN '2022-01-01' AND CURRENT_DATEGROUP BY p.dodHAVING COUNT(a.hadm_id) > 1
# Count is  1147
# efed4e108b270dda785398e4:SELECT d_icd_diagnoses.icd_code,       d_icd_diagnoses.long_title,       (COUNT(DISTINCT CASE                           WHEN patients.dod IS NOT NULL THEN patients.subject_id                       END)::FLOAT / NULLIF(COUNT(DISTINCT patients.subject_id), 0)) * 100 AS mortality_rateFROM patientsJOIN diagnoses_icd ON patients.subject_id = diagnoses_icd.subject_idJOIN d_icd_diagnoses ON diagnoses_icd.icd_code = d_icd_diagnoses.icd_codeWHERE patients.dod IS NOT NULL  AND patients.dod <= (CURRENT_DATE - INTERVAL '3 months')GROUP BY d_icd_diagnoses.icd_code,         d_icd_diagnoses.long_titleORDER BY mortality_rate DESC NULLS LASTLIMIT 5
# Count is  1148
# 4339559d1ee0ea11e76a0116:null
# Count is  1149
# b79b244dc972c7cd9869e514:null
# Count is  1150
# 72e0ab522c86eeb3cfdf64d1:null
# Count is  1151
# 9df13449259f96705f0f7f56:SELECT AVG(EXTRACT(YEAR                   FROM AGE(CURRENT_DATE, p.dob))) AS average_ageFROM patients pJOIN admissions a ON p.subject_id = a.subject_idWHERE p.gender = 'F'  AND a.age <= 30
# Count is  1152
# 9637bc783f8bbca836af73b7:SELECT MAX(i.charttime) AS last_input_timeFROM inputevents iWHERE i.subject_id = 10021487  AND i.charttime > '2021-12-06'
# Count is  1153
# 6e1576f187e4e615357171a1:null
# Count is  1154
# 5005783fa8c512e359aa1830:SELECT p.row_idFROM patients pJOIN diagnoses_icd d ON p.subject_id = d.subject_idWHERE d.icd_code = '99731'  AND EXTRACT(YEAR              FROM d.charttime) = 2021
# Count is  1155
# 8101d176c45f4e285b9e9540:SELECT COUNT(DISTINCT p.subject_id) AS patient_countFROM patients pJOIN diagnoses_icd d ON p.subject_id = d.subject_idJOIN prescriptions pr ON p.subject_id = pr.subject_idWHERE d.icd_code = 'A05.0'  AND pr.drug = 'ferric gluconate'  AND EXTRACT(YEAR              FROM d.charttime) >= 2021  AND EXTRACT(MONTH              FROM d.charttime) <= EXTRACT(MONTH                                           FROM pr.starttime) + 2
# Count is  1156
# 3c047df90cc7adaa81c0470e:SELECT icustays.last_careunitFROM patientsJOIN admissions ON patients.subject_id = admissions.subject_idJOIN icustays ON admissions.stay_id = icustays.stay_idWHERE patients.subject_id = 10009049ORDER BY icustays.stay_id DESCLIMIT 1
# Count is  1157
# d8c4bcdab05c48a114af4957:SELECT SUM(o.value) AS total_outputFROM outputevents oJOIN patients p ON o.subject_id = p.subject_idWHERE p.subject_id = 10027602  AND o.charttime >= '2021-06-22'
# Count is  1158
# d6ea3c0d783fc7759f292e34:SELECT MAX(i.outtime - i.intime) AS longest_icu_stay_durationFROM icustays iWHERE i.acuity_score = 10
# Count is  1159
# 73710b96b938a24a7a5c86d5:SELECT p.drugFROM prescriptions pWHERE p.subject_id = 10014729ORDER BY p.starttime ASCLIMIT 1
# Count is  1160
# 9cdee4aaa2811035370a1c86:SELECT AVG(p.weight) AS average_weightFROM patients pJOIN admissions a ON p.subject_id = a.subject_idWHERE p.subject_id = 10039831  AND EXTRACT(MONTH              FROM a.admittime) = 7  AND EXTRACT(YEAR              FROM a.admittime) = 2021
# Count is  1161
# e2740d72774b525d272c8e62:null
# Count is  1162
# 95a9526ece941edd7c72f13d:SELECT AVG(c.cost) AS average_costFROM cost cJOIN d_labitems l ON c.event_id = l.itemidWHERE l.label ilike '%triglycer%'
# Count is  1163
# 41d96d1ac69af1608ab8e287:SELECT EXTRACT(YEAR               FROM i.charttime) AS YEAR,       MAX(i.valuenum) AS max_valuenumFROM inputevents iWHERE i.subject_id = 10019777  AND i.itemid IN    (SELECT itemid     FROM d_items     WHERE linksto = 'vitals')GROUP BY YEARORDER BY YEAR
# Count is  1164
# 01eb9179a54a0f80fb0189a6:SELECT d_icd_procedures.long_title,       COUNT(*) AS procedure_countFROM patientsJOIN admissions ON patients.subject_id = admissions.subject_idJOIN diagnoses_icd ON admissions.hadm_id = diagnoses_icd.hadm_idJOIN d_icd_procedures ON diagnoses_icd.icd_code = d_icd_procedures.icd_codeWHERE patients.dod BETWEEN '2021-01-01' AND '2021-12-31'  AND d_icd_diagnoses.long_title ILIKE '%pain%left%shoulder%'  AND d_icd_procedures.long_title IN    (SELECT long_title     FROM d_icd_procedures     WHERE EXTRACT(YEAR                   FROM chargetime) = 2021)GROUP BY d_icd_procedures.long_titleORDER BY procedure_count DESCLIMIT 5
# Count is  1165
# e65c919605b77138aef522fe:SELECT d_icd_procedures.long_titleFROM patientsJOIN admissions ON patients.subject_id = admissions.subject_idJOIN procedures_icd ON admissions.hadm_id = procedures_icd.subject_idJOIN d_icd_procedures ON procedures_icd.icd_code = d_icd_procedures.icd_codeWHERE patients.subject_id = 10019777  AND admissions.admittime >= (CURRENT_DATE - INTERVAL '21 months')GROUP BY d_icd_procedures.long_titleHAVING COUNT(procedures_icd.icd_code) >= 2
# Count is  1166
# acf40b3eb276cefbbd1f51be:SELECT percent_rank() OVER (                            ORDER BY 8.0) AS percentile_rankFROM  (SELECT percentile_cont(0.1) OVER (                                     ORDER BY 8.0) AS percentile_cont_0_1   FROM     (SELECT age      FROM admissions      WHERE subject_id = 10022017      LIMIT 1)) AS subquery
# Count is  1167

# %%
# sqls = []
# i=0
# for question in questions:
#     sql = generate_query(question)
#     if 'Humne kiya' in sql:
#       sql = 'null'
#     sqls.append(sql.replace('\n', ''))
#     print(sql)
#     i+=1
#     print("Count is ",i)
